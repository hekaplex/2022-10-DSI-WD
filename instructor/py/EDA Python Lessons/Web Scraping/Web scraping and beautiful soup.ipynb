# %% [markdown]
# # Lesson 7: Advanced Web Scraping and Data Gathering
# ## Topic 1: Basics of web-scraping using `requests` and `BeautifulSoup` libraries

# %% [markdown]
# ### Import `requests` library

# %%
# !pip install beautifulsoup4

# %%
import requests

# %% [markdown]
# ### Exercise 1: Use `requests` to get a response from the Wikipedia home page

# %%
# First assign the URL of Wikipedia home page to a string 
wiki_home = "https://en.wikipedia.org/wiki/Main_Page"

# %%
# Use the 'get' method from requests library to get a response
response = requests.get(wiki_home)

# %%
# What is this 'response' object anyway
type(response)
# Out:
# requests.models.Response

# %%
for r in response: print(r)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclo'
# b'pedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":['
# b'"",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May"'
# b',"June","July","August","September","October","November","December"],"wgRequestId":"2905378d-a6f4-4e8c-890c-386978280edf","wgCSP'
# b'Nonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitl'
# b'e":"Main Page","wgCurRevisionId":1108085777,"wgRevisionId":1108085777,"wgArticleId":15580374,"wgIsArticle":true,"wgIsRedirect":f'
# b'alse,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel'
# b'":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":false,"wgRelevantPageIsProba'
# b'blyEditable":false,"wgRestrictionEdit":["sysop"],"wgRestrictionMove":["sysop"],"wgIsMainPage":true,"wgFlaggedRevsParams":{\n"tags'
# b'":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFD'
# b'isplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample'
# b'":false,"wgWMEPageLength":3000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,"wgMediaV'
# b'iewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralA'
# b'uthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q5296","GEHomepageS'
# b'uggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false};RL'
# b'STATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"'
# b'ready","user.options":"loading","skins.vector.styles.legacy":"ready",\n"ext.visualEditor.desktopArticleTarget.noscript":"ready","'
# b'ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready"};RLPAGEMODULES=["site","mediawiki.page.ready","skins.vector.legacy.'
# b'js","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.event'
# b'Logging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNoti'
# b'ce.startUp","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext'
# b'.centralauth.centralautologin","ext.popups","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];</script>\n<script>'
# b'(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.s'
# b'et({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&'
# b'amp;modules=ext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cskins.vector.styles.l'
# b'egacy&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw='
# b'1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang'
# b'=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n<meta name="generator" content="MediaWiki 1.40.0-wmf.2"/>\n<meta n'
# b'ame="referrer" content="origin"/>\n<meta name="referrer" content="origin-when-crossorigin"/>\n<meta name="referrer" content="origi'
# b'n-when-cross-origin"/>\n<meta name="format-detection" content="telephone=no"/>\n<meta property="og:image" content="https://upload.'
# b'wikimedia.org/wikipedia/commons/thumb/0/07/Portland_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg/1200px-Portland'
# b'_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg"/>\n<meta property="og:image:width" content="1200"/>\n<meta property'
# b'="og:image:height" content="775"/>\n<meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/0/07/'
# b'Portland_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg/800px-Portland_Streetcar_car_023_at_west_end_of_Broadway_B'
# b'ridge_in_2016.jpg"/>\n<meta property="og:image:width" content="800"/>\n<meta property="og:image:height" content="517"/>\n<meta prop'
# b'erty="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/0/07/Portland_Streetcar_car_023_at_west_end_of_Bro'
# b'adway_Bridge_in_2016.jpg/640px-Portland_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg"/>\n<meta property="og:image'
# b':width" content="640"/>\n<meta property="og:image:height" content="414"/>\n<meta name="viewport" content="width=1000"/>\n<meta prop'
# b'erty="og:title" content="Wikipedia, the free encyclopedia"/>\n<meta property="og:type" content="website"/>\n<link rel="preconnect"'
# b' href="//upload.wikimedia.org"/>\n<link rel="alternate" media="only screen and (max-width: 720px)" href="//en.m.wikipedia.org/wik'
# b'i/Main_Page"/>\n<link rel="alternate" type="application/atom+xml" title="Wikipedia picture of the day feed" href="/w/api.php?acti'
# b'on=featuredfeed&amp;feed=potd&amp;feedformat=atom"/>\n<link rel="alternate" type="application/atom+xml" title="Wikipedia featured'
# b' articles feed" href="/w/api.php?action=featuredfeed&amp;feed=featured&amp;feedformat=atom"/>\n<link rel="alternate" type="applic'
# b'ation/atom+xml" title="Wikipedia &quot;On this day...&quot; feed" href="/w/api.php?action=featuredfeed&amp;feed=onthisday&amp;fe'
# b'edformat=atom"/>\n<link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>\n<link rel="icon" href="/static/favicon/'
# b'wikipedia.ico"/>\n<link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia '
# b'(en)"/>\n<link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>\n<link rel="license" href'
# b'="https://creativecommons.org/licenses/by-sa/3.0/"/>\n<link rel="canonical" href="https://en.wikipedia.org/wiki/Main_Page"/>\n<lin'
# b'k rel="dns-prefetch" href="//meta.wikimedia.org" />\n<link rel="dns-prefetch" href="//login.wikimedia.org"/>\n</head>\n<body class='
# b'"mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Main_Page rootpage-Main_Page skin-vector action-view skin-vect'
# b'or-legacy vector-toc-not-collapsed vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disable'
# b'd vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-sticky-header-edit-disab'
# b'led vector-feature-table-of-contents-disabled vector-feature-visual-enhancement-next-disabled"><div id="mw-page-base" class="nop'
# b'rint"></div>\n<div id="mw-head-base" class="noprint"></div>\n<div id="content" class="mw-body" role="main">\n\t<a id="top"></a>\n\t<di'
# b'v id="siteNotice"><!-- CentralNotice --></div>\n\t<div class="mw-indicators">\n\t</div>\n\t<h1 id="firstHeading" class="firstHeading m'
# b'w-first-heading" style="display: none"><span class="mw-page-title-main">Main Page</span></h1>\n\t<div id="bodyContent" class="vect'
# b'or-body">\n\t\t<div id="siteSub" class="noprint">From Wikipedia, the free encyclopedia</div>\n\t\t<div id="contentSub"></div>\n\t\t<div i'
# b'd="contentSub2"></div>\n\t\t\n\t\t<div id="jump-to-nav"></div>\n\t\t<a class="mw-jump-link" href="#mw-head">Jump to navigation</a>\n\t\t<a c'
# b'lass="mw-jump-link" href="#searchInput">Jump to search</a>\n\t\t<div id="mw-content-text" class="mw-body-content mw-content-ltr" la'
# b'ng="en" dir="ltr"><div class="mw-parser-output"><style data-mw-deduplicate="TemplateStyles:r1094834805">.mw-parser-output .mp-bo'
# b'x{border:1px solid #aaa;padding:0 0.5em 0.5em;margin-top:4px}.mw-parser-output .mp-h2,body.skin-timeless .mw-parser-output .mp-h'
# b'2{border:1px solid #aaa;margin:0.5em 0;padding:0.2em 0.4em;font-size:120%;font-weight:bold;font-family:inherit}.mw-parser-output'
# b' h2.mp-h2::after{border:none}.mw-parser-output .mp-later{font-size:85%;font-weight:normal}.mw-parser-output #mp-topbanner{backgr'
# b'ound:#f9f9f9;border-color:#ddd}.mw-parser-output #mp-welcomecount{text-align:center;margin:0.4em}.mw-parser-output #mp-welcome{f'
# b'ont-size:162%;padding:0.1em}.mw-parser-output #mp-welcome h1{font-size:inherit;font-family:inherit;display:inline;border:none}.m'
# b'w-parser-output #mp-welcome h1::after{content:none}.mw-parser-output #mp-free{font-size:95%}.mw-parser-output #articlecount{font'
# b'-size:85%}.mw-parser-output .mp-contains-float::after{content:"";display:block;clear:both}.mw-parser-output #mp-banner{backgroun'
# b'd:#fffaf5;border-color:#f2e0ce}.mw-parser-output #mp-left{background:#f5fffa;border-color:#cef2e0}.mw-parser-output #mp-left .mp'
# b'-h2{background:#cef2e0;border-color:#a3bfb1}.mw-parser-output #mp-right{background:#f5faff;border-color:#cedff2}.mw-parser-outpu'
# b't #mp-right .mp-h2{background:#cedff2;border-color:#a3b0bf}.mw-parser-output #mp-middle{background:#fff5fa;border-color:#f2cedd}'
# b'.mw-parser-output #mp-middle .mp-h2{background:#f2cedd;border-color:#bfa3af}.mw-parser-output #mp-lower{background:#faf5ff;borde'
# b'r-color:#ddcef2}.mw-parser-output #mp-lower .mp-h2{background:#ddcef2;border-color:#afa3bf}.mw-parser-output #mp-bottom{border-c'
# b'olor:#e2e2e2}.mw-parser-output #mp-bottom .mp-h2{background:#eee;border-color:#ddd}@media(max-width:875px){.mw-parser-output #mp'
# b'-tfp table,.mw-parser-output #mp-tfp tr,.mw-parser-output #mp-tfp td,.mw-parser-output #mp-tfp tbody{display:block!important;wid'
# b'th:100%!important;box-sizing:border-box}.mw-parser-output #mp-tfp tr:first-child td:first-child a{text-align:center;display:tabl'
# b'e;margin:0 auto}}@media(min-width:875px){.mw-parser-output #mp-upper{display:flex}.mw-parser-output #mp-left{flex:1 1 55%;margin'
# b'-right:2px}.mw-parser-output #mp-right{flex:1 1 45%;margin-left:2px}}.mw-parser-output div.hlist.inline ul,.mw-parser-output div'
# b'.hlist.inline li,.mw-parser-output div.hlist.inline{display:inline}</style>\n<div id="mp-topbanner" class="mp-box">\n<div id="mp-w'
# b'elcomecount">\n<div id="mp-welcome"><h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" '
# b'title="Wikipedia">Wikipedia</a></span></h1>,</div>\n<div id="mp-free">the <a href="/wiki/Free_content" title="Free content">free<'
# b'/a> <a href="/wiki/Encyclopedia" title="Encyclopedia">encyclopedia</a> that <a href="/wiki/Help:Introduction_to_Wikipedia" title'
# b'="Help:Introduction to Wikipedia">anyone can edit</a>.</div>\n<div id="articlecount"><a href="/wiki/Special:Statistics" title="Sp'
# b'ecial:Statistics">6,553,743</a> articles in <a href="/wiki/English_language" title="English language">English</a></div>\n</div>\n<'
# b'/div>\n<div id="mp-upper">\n<div id="mp-left" class="MainPageBG mp-box">\n<h2 id="mp-tfa-h2" class="mp-h2"><span id="From_today.27s'
# b'_featured_article"></span><span class="mw-headline" id="From_today\'s_featured_article">From today\'s featured article</span></h2>'
# b'\n<div id="mp-tfa" class="mp-contains-float"><div id="mp-tfa-img" style="float: left; margin: 0.5em 0.9em 0.4em 0em;">\n<div class'
# b'="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 174px;">\n<a href="/wiki/File:Portlan'
# b'd_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg" class="image" title="Portland Streetcar vehicle on the Broadway '
# b'Bridge"><img alt="Portland Streetcar vehicle on the Broadway Bridge" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/07/Po'
# b'rtland_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg/174px-Portland_Streetcar_car_023_at_west_end_of_Broadway_Bri'
# b'dge_in_2016.jpg" decoding="async" width="174" height="112" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/07/Portland_'
# b'Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg/261px-Portland_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_'
# b'2016.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/07/Portland_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_'
# b'2016.jpg/348px-Portland_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg 2x" data-file-width="1800" data-file-height'
# b'="1163" /></a><div class="thumbcaption" style="padding: 0.25em 0; word-wrap: break-word;">Portland Streetcar vehicle on the Broa'
# b'dway Bridge</div></div>\n</div>\n<p>The <b><a href="/wiki/A_and_B_Loop" title="A and B Loop">A and B&#160;Loop</a></b> is a <a hre'
# b'f="/wiki/Tram" title="Tram">streetcar</a> circle route of the <a href="/wiki/Portland_Streetcar" title="Portland Streetcar">Port'
# b'land Streetcar</a> system in <a href="/wiki/Portland,_Oregon" title="Portland, Oregon">Portland, Oregon</a>, United States. Oper'
# b'ated by Portland Streetcar, Inc. and <a href="/wiki/TriMet" title="TriMet">TriMet</a>, it consists of two services within the Ce'
# b'ntral City that travel a loop between the east and west sides of the <a href="/wiki/Willamette_River" title="Willamette River">W'
# b'illamette River</a> by crossing the <a href="/wiki/Broadway_Bridge_(Portland,_Oregon)" title="Broadway Bridge (Portland, Oregon)'
# b'">Broadway Bridge</a> <i>(pictured)</i> in the north and <a href="/wiki/Tilikum_Crossing" title="Tilikum Crossing">Tilikum Cross'
# b'ing</a> in the south. The services connect <a href="/wiki/Downtown_Portland,_Oregon" title="Downtown Portland, Oregon">Portland\''
# b's downtown</a>, <a href="/wiki/Pearl_District,_Portland,_Oregon" title="Pearl District, Portland, Oregon">Pearl District</a>, <a'
# b' href="/wiki/Lloyd_District,_Portland,_Oregon" title="Lloyd District, Portland, Oregon">Lloyd District</a>, <a href="/wiki/Centr'
# b'al_Eastside,_Portland,_Oregon" title="Central Eastside, Portland, Oregon">Central Eastside</a>, and <a href="/wiki/South_Waterfr'
# b'ont,_Portland,_Oregon" title="South Waterfront, Portland, Oregon">South Waterfront</a>. Portland city officials considered an ea'
# b'stside streetcar extension upon authorizing the <a href="/wiki/NS_Line" title="NS Line">Central City Streetcar</a> project in 19'
# b'97. After several years of planning, the Portland Streetcar Loop Project was approved and held its groundbreaking in 2009. It op'
# b'ened between the Broadway Bridge and the <a href="/wiki/Oregon_Museum_of_Science_and_Industry" title="Oregon Museum of Science a'
# b'nd Industry">Oregon Museum of Science and Industry</a> on September&#160;22, 2012. The opening of Tilikum Crossing in 2015 furth'
# b'er extended its tracks from the museum to the South Waterfront and completed the loop. (<b><a href="/wiki/A_and_B_Loop" title="A'
# b' and B Loop">Full&#160;article...</a></b>)\n</p>\n<div class="tfa-recent" style="text-align: right;">\nRecently featured: <div clas'
# b's="hlist hlist-separated inline">\n<ul><li><a href="/wiki/Alexander_Cameron_Rutherford" title="Alexander Cameron Rutherford">Alex'
# b'ander Cameron Rutherford</a></li>\n<li><a href="/wiki/A.C._Monza" title="A.C. Monza">A.C. Monza</a></li>\n<li><a href="/wiki/Eliza'
# b'beth_II" title="Elizabeth II">Elizabeth&#160;II</a></li></ul>\n</div></div>\n<div class="hlist hlist-separated tfa-footer noprint"'
# b' style="text-align:right;">\n<ul><li><b><a href="/wiki/Wikipedia:Today%27s_featured_article/September_2022" title="Wikipedia:Toda'
# b'y&#39;s featured article/September 2022">Archive</a></b></li>\n<li><b><a href="https://lists.wikimedia.org/postorius/lists/daily-'
# b'article-l.lists.wikimedia.org/" class="extiw" title="mail:daily-article-l">By email</a></b></li>\n<li><b><a href="/wiki/Wikipedia'
# b':Featured_articles" title="Wikipedia:Featured articles">More featured articles</a></b></li>\n<li><b><a href="/wiki/Wikipedia:Abou'
# b't_Today%27s_featured_article" title="Wikipedia:About Today&#39;s featured article">About</a></b></li></ul>\n</div></div>\n<h2 id="'
# b'mp-dyk-h2" class="mp-h2"><span class="mw-headline" id="Did_you_know_...">Did you know&#160;...</span></h2>\n<div id="mp-dyk" clas'
# b's="mp-contains-float">\n<div class="dyk-img" style="float: right; margin-left: 0.5em;">\n<div class="thumbinner mp-thumb" style="b'
# b'ackground: transparent; border: none; padding: 0; max-width: 101px;">\n<a href="/wiki/File:San_Remo_apartments_from_Central_Park,'
# b'_NYC.jpg" class="image" title="The San Remo"><img alt="The San Remo" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a1/Sa'
# b'n_Remo_apartments_from_Central_Park%2C_NYC.jpg/101px-San_Remo_apartments_from_Central_Park%2C_NYC.jpg" decoding="async" width="1'
# b'01" height="195" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a1/San_Remo_apartments_from_Central_Park%2C_NYC.jpg/15'
# b'2px-San_Remo_apartments_from_Central_Park%2C_NYC.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a1/San_Remo_apartmen'
# b'ts_from_Central_Park%2C_NYC.jpg/202px-San_Remo_apartments_from_Central_Park%2C_NYC.jpg 2x" data-file-width="1828" data-file-heig'
# b'ht="3525" /></a><div class="thumbcaption" style="padding: 0.25em 0; word-wrap: break-word;">The San Remo</div></div>\n</div>\n<ul>'
# b'<li>... that <b><a href="/wiki/The_San_Remo" title="The San Remo">the San Remo</a></b> <i>(pictured)</i> was once described as a'
# b'n "ATM for Democratic presidential campaigns" in the United States?</li>\n<li>... that the shop in Cairo designed by <b><a href="'
# b'/wiki/Robert_Williams_(architect)" title="Robert Williams (architect)">Robert Williams</a></b> for the <b><a href="/wiki/John_Da'
# b'vies_Bryan" title="John Davies Bryan">Davies Bryan Company</a></b> became a site of "pilgrimage for all Welsh travellers" to Egy'
# b'pt?</li>\n<li>... that <a href="/wiki/Pedro_II_of_Brazil" title="Pedro II of Brazil">Pedro&#160;II of Brazil</a> examined the sig'
# b'nal system on the <b><a href="/wiki/Fitchburg_Cutoff" title="Fitchburg Cutoff">Fitchburg Cutoff</a></b>?</li>\n<li>... that when '
# b'<b><a href="/wiki/Francesco_Lanzillotta" title="Francesco Lanzillotta">Francesco Lanzillotta</a></b> conducted Dallapiccola\'s <i'
# b'><a href="/wiki/Ulisse" title="Ulisse">Ulisse</a></i> at <a href="/wiki/Oper_Frankfurt" title="Oper Frankfurt">Oper Frankfurt</a'
# b'> in 2022, a reviewer noted that he "does not shy away from agglomerations of sound"?</li>\n<li>... that in 2009, residents of Ma'
# b'ine <b><a href="/wiki/2009_Maine_Question_1" title="2009 Maine Question 1">voted to repeal a law</a></b> that would have legaliz'
# b'ed same-sex marriage?</li>\n<li>... that yachting photographer <b><a href="/wiki/Eileen_Ramsay_(photographer)" title="Eileen Rams'
# b'ay (photographer)">Eileen Ramsay</a></b> damaged many <a href="/wiki/Rolleiflex" title="Rolleiflex">Rolleiflex</a> cameras by at'
# b'tempting to take photos at water level?</li>\n<li>... that "<b><a href="/wiki/Illegal_operation" title="Illegal operation">illega'
# b'l operation</a></b>" was a common euphemism for <a href="/wiki/Abortion" title="Abortion">abortion</a> in early-20th-century Nor'
# b'th American newspapers?</li>\n<li>... that Ekuikui&#160;V was deposed as the king of <b><a href="/wiki/Bailundo_(kingdom)" title='
# b'"Bailundo (kingdom)">Bailundo</a></b> in 2021 and sentenced to six years in prison?</li></ul>\n<div class="hlist hlist-separated '
# b'dyk-footer noprint" style="margin-top: 0.5em; text-align: right;">\n<ul><li><b><a href="/wiki/Wikipedia:Recent_additions" title="'
# b'Wikipedia:Recent additions">Archive</a></b></li>\n<li><b><a href="/wiki/Help:Your_first_article" title="Help:Your first article">'
# b'Start a new article</a></b></li>\n<li><b><a href="/wiki/Template_talk:Did_you_know" title="Template talk:Did you know">Nominate a'
# b'n article</a></b></li></ul>\n</div>\n</div>\n</div>\n<div id="mp-right" class="MainPageBG mp-box">\n<h2 id="mp-itn-h2" class="mp-h2">'
# b'<span class="mw-headline" id="In_the_news">In the news</span></h2>\n<div id="mp-itn" class="mp-contains-float"><style data-mw-ded'
# b'uplicate="TemplateStyles:r1053378754">.mw-parser-output .itn-img{float:right;margin-left:0.5em;margin-top:0.2em}</style><div rol'
# b'e="figure" class="itn-img">\n<div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width'
# b': 123px;">\n<a href="/wiki/File:Jean-Luc_Godard_at_Berkeley,_1968.jpg" class="image" title="Jean-Luc Godard in 1968"><img alt="Je'
# b'an-Luc Godard in 1968" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Jean-Luc_Godard_at_Berkeley%2C_1968.jpg/121px-Je'
# b'an-Luc_Godard_at_Berkeley%2C_1968.jpg" decoding="async" width="121" height="161" class="thumbborder" srcset="//upload.wikimedia.'
# b'org/wikipedia/commons/thumb/f/f9/Jean-Luc_Godard_at_Berkeley%2C_1968.jpg/182px-Jean-Luc_Godard_at_Berkeley%2C_1968.jpg 1.5x, //u'
# b'pload.wikimedia.org/wikipedia/commons/thumb/f/f9/Jean-Luc_Godard_at_Berkeley%2C_1968.jpg/242px-Jean-Luc_Godard_at_Berkeley%2C_19'
# b'68.jpg 2x" data-file-width="600" data-file-height="800" /></a><div class="thumbcaption" style="padding: 0.25em 0; word-wrap: bre'
# b'ak-word; text-align: left;">Jean-Luc Godard <span class="nowrap">in 1968</span></div></div>\n</div>\n<ul><li><b><a href="/wiki/Sep'
# b'tember_2022_Iranian_protests" class="mw-redirect" title="September 2022 Iranian protests">Protests in Iran</a></b> following the'
# b' <b><a href="/wiki/Death_of_Mahsa_Amini" title="Death of Mahsa Amini">death of Mahsa Amini</a></b> leave more than 30 people dea'
# b'd.</li>\n<li>At least 100 people are killed in <b><a href="/wiki/2022_Kyrgyzstan%E2%80%93Tajikistan_clashes" title="2022 Kyrgyzst'
# b'an\xe2\x80\x93Tajikistan clashes">renewed fighting</a></b> between Kyrgyzstan and Tajikistan.</li>\n<li>In <b><a href="/wiki/2022_Swedish_'
# b'general_election" title="2022 Swedish general election">the Swedish general election</a></b>, the <a href="/wiki/Sweden_Democrat'
# b's" title="Sweden Democrats">Sweden Democrats</a>\xe2\x80\x93<a href="/wiki/Moderate_Party" title="Moderate Party">Moderates</a>\xe2\x80\x93<a href'
# b'="/wiki/Christian_Democrats_(Sweden)" title="Christian Democrats (Sweden)">Christian Democrats</a>\xe2\x80\x93<a href="/wiki/Liberals_(Sw'
# b'eden)" title="Liberals (Sweden)">Liberals</a> bloc wins a majority of seats in the <a href="/wiki/Riksdag" title="Riksdag">Riksd'
# b'ag</a>.</li>\n<li>French-Swiss filmmaker <b><a href="/wiki/Jean-Luc_Godard" title="Jean-Luc Godard">Jean-Luc Godard</a></b> <i>(p'
# b'ictured)</i> dies at the <span class="nowrap">age of 91</span>.</li></ul>\n<div class="itn-footer" style="margin-top: 0.5em;">\n<d'
# b'iv><b><a href="/wiki/Portal:Current_events" title="Portal:Current events">Ongoing</a></b>: <div class="hlist hlist-separated inl'
# b'ine">\n<ul><li><a href="/wiki/2022_Russian_invasion_of_Ukraine" title="2022 Russian invasion of Ukraine">Russian invasion of Ukra'
# b'ine</a></li></ul></div></div>\n<div><b><a href="/wiki/Deaths_in_2022" title="Deaths in 2022">Recent deaths</a></b>&#58; <div clas'
# b's="hlist hlist-separated inline">\n<ul><li><a href="/wiki/Liam_Holden" title="Liam Holden">Liam Holden</a></li>\n<li><a href="/wik'
# b'i/Nick_Holonyak" title="Nick Holonyak">Nick Holonyak</a></li>\n<li><span class="nowrap"><a href="/wiki/Allan_M._Siegal" title="Al'
# b'lan M. Siegal">Allan M. Siegal</a></span></li>\n<li><a href="/wiki/Maury_Wills" title="Maury Wills">Maury Wills</a></li>\n<li><a h'
# b'ref="/wiki/Herb_Lusk" title="Herb Lusk">Herb Lusk</a></li>\n<li><a href="/wiki/Raju_Srivastav" title="Raju Srivastav">Raju Srivas'
# b'tav</a></li></ul></div></div></div>\n<div class="hlist hlist-separated itn-footer noprint" style="text-align:right;">\n<ul><li><b>'
# b'<a href="/wiki/Wikipedia:In_the_news/Candidates" title="Wikipedia:In the news/Candidates">Nominate an article</a></b></li></ul>\n'
# b'</div></div>\n<h2 id="mp-otd-h2" class="mp-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>\n<div id="mp-otd'
# b'" class="mp-contains-float">\n<p><b><a href="/wiki/September_22" title="September 22">September 22</a></b>\n</p>\n<div style="float'
# b':right;margin-left:0.5em;" id="mp-otd-img">\n<div class="thumbinner mp-thumb" style="background: transparent; border: none; paddi'
# b'ng: 0; max-width: 130px;">\n<a href="/wiki/File:Richardwagner1.jpg" class="image" title="Richard Wagner"><img alt="Richard Wagner'
# b'" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/eb/Richardwagner1.jpg/130px-Richardwagner1.jpg" decoding="async" width="'
# b'130" height="151" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/eb/Richardwagner1.jpg/195px-Richardwagner1.jpg 1.5x, '
# b'//upload.wikimedia.org/wikipedia/commons/e/eb/Richardwagner1.jpg 2x" data-file-width="260" data-file-height="301" /></a><div cla'
# b'ss="thumbcaption" style="padding: 0.25em 0; word-wrap: break-word;">Richard Wagner</div></div>\n</div>\n<ul><li><a href="/wiki/158'
# b'6" title="1586">1586</a> \xe2\x80\x93 <a href="/wiki/Eighty_Years%27_War" title="Eighty Years&#39; War">Eighty Years\' War</a>: Spanish fo'
# b'rces defeated an Anglo-Dutch army at the <b><a href="/wiki/Battle_of_Zutphen" title="Battle of Zutphen">Battle of Zutphen</a></b'
# b'>.</li>\n<li><a href="/wiki/1869" title="1869">1869</a> \xe2\x80\x93 <i><b><a href="/wiki/Das_Rheingold" title="Das Rheingold">Das Rheingo'
# b'ld</a></b></i>, the first of four operas in <i><a href="/wiki/Der_Ring_des_Nibelungen" title="Der Ring des Nibelungen">Der Ring '
# b'des Nibelungen</a></i> by the German composer <a href="/wiki/Richard_Wagner" title="Richard Wagner">Richard Wagner</a> <i>(pictu'
# b'red)</i>, was first performed in Munich.</li>\n<li><a href="/wiki/1934" title="1934">1934</a> \xe2\x80\x93 One of Britain\'s worst mining a'
# b'ccidents took place when <b><a href="/wiki/Gresford_disaster" title="Gresford disaster">an explosion</a></b> at <a href="/wiki/G'
# b'resford_Colliery" title="Gresford Colliery">Gresford Colliery</a> in Wales killed 266 men.</li>\n<li><a href="/wiki/1979" title="'
# b'1979">1979</a> \xe2\x80\x93 An American <a href="/wiki/Vela_(satellite)" title="Vela (satellite)">Vela</a> satellite detected <b><a href='
# b'"/wiki/Vela_incident" title="Vela incident">an unidentified flash of light</a></b> near the <a href="/wiki/Prince_Edward_Islands'
# b'" title="Prince Edward Islands">Prince Edward Islands</a> in the Indian Ocean, thought to be a <a href="/wiki/Nuclear_weapons_te'
# b'sting" title="Nuclear weapons testing">nuclear weapons test</a>.</li>\n<li><a href="/wiki/1994" title="1994">1994</a> \xe2\x80\x93 The <b>'
# b'<a href="/wiki/Nordhordland_Bridge" title="Nordhordland Bridge">Nordhordland Bridge</a></b>, crossing <a href="/wiki/Salhusfjord'
# b'en" title="Salhusfjorden">Salhusfjorden</a> between <a href="/wiki/Klauvaneset" title="Klauvaneset">Klauvaneset</a> and <a href='
# b'"/wiki/Flat%C3%B8y" title="Flat\xc3\xb8y">Flat\xc3\xb8y</a> in <a href="/wiki/Vestland" title="Vestland">Vestland</a>, and Norway\'s second-l'
# b'ongest bridge, officially opened.</li></ul>\n<div class="hlist hlist-separated" style="margin-top: 0.5em;"><ul><li><b><a href="/w'
# b'iki/Wilhelm_Keitel" title="Wilhelm Keitel">Wilhelm Keitel</a></b>  (<abbr title="born">b.</abbr>&#160;1882)</li><li><b><a href="'
# b'/wiki/Norma_McCorvey" title="Norma McCorvey">Norma McCorvey</a></b>  (<abbr title="born">b.</abbr>&#160;1947)</li><li><b><a href'
# b'="/wiki/Aurelio_L%C3%B3pez" title="Aurelio L\xc3\xb3pez">Aurelio L\xc3\xb3pez</a></b>  (<abbr title="died">d.</abbr>&#160;1992)</li></ul></d'
# b'iv>\n<div style="margin-top:0.5em;">\nMore anniversaries: <div class="hlist hlist-separated inline nowraplinks">\n<ul><li><a href="'
# b'/wiki/September_21" title="September 21">September 21</a></li>\n<li><b><a href="/wiki/September_22" title="September 22">Septembe'
# b'r 22</a></b></li>\n<li><a href="/wiki/September_23" title="September 23">September 23</a></li></ul>\n</div></div>\n<div class="hlis'
# b't hlist-separated otd-footer noprint" style="text-align:right;">\n<ul><li><b><a href="/wiki/Wikipedia:Selected_anniversaries/Sept'
# b'ember" title="Wikipedia:Selected anniversaries/September">Archive</a></b></li>\n<li><b><a href="https://lists.wikimedia.org/posto'
# b'rius/lists/daily-article-l.lists.wikimedia.org/" class="extiw" title="mail:daily-article-l">By email</a></b></li>\n<li><b><a href'
# b'="/wiki/List_of_days_of_the_year" title="List of days of the year">List of days of the year</a></b></li></ul>\n</div></div>\n</div'
# b'>\n</div>\n<div id="mp-lower" class="MainPageBG mp-box">\n<h2 id="mp-tfp-h2" class="mp-h2"><span id="Today.27s_featured_picture"></'
# b'span><span class="mw-headline" id="Today\'s_featured_picture">Today\'s featured picture</span></h2>\n<div id="mp-tfp">\n<table role='
# b'"presentation" style="margin:0 3px 3px; width:100%; box-sizing:border-box; text-align:left; background-color:transparent; border'
# b'-collapse:collapse;">\n<tbody><tr>\n<td style="padding:0 0.9em 0 0; width:300px;"><a href="/wiki/File:On%C3%A9sime_Reclus_Nadar_GA'
# b'LLICA.jpg" class="image" title="On\xc3\xa9sime Reclus"><img alt="On\xc3\xa9sime Reclus" src="//upload.wikimedia.org/wikipedia/commons/thumb/'
# b'f/fd/On%C3%A9sime_Reclus_Nadar_GALLICA.jpg/300px-On%C3%A9sime_Reclus_Nadar_GALLICA.jpg" decoding="async" width="300" height="429'
# b'" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fd/On%C3%A9sime_Reclus_Nadar_GALLICA.jpg/450px-On%C3%A9sime_Reclus_Na'
# b'dar_GALLICA.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fd/On%C3%A9sime_Reclus_Nadar_GALLICA.jpg/600px-On%C3%A9si'
# b'me_Reclus_Nadar_GALLICA.jpg 2x" data-file-width="2365" data-file-height="3382" /></a>\n</td>\n<td style="padding:0 6px 0 0">\n<p><b'
# b'><a href="/wiki/On%C3%A9sime_Reclus" title="On\xc3\xa9sime Reclus">On\xc3\xa9sime Reclus</a></b> (22&#160;September 1837&#160;\xe2\x80\x93 30&#160;Ju'
# b'ne 1916), was a French <a href="/wiki/Geographer" title="Geographer">geographer</a> who specialized in the relations between Fra'
# b'nce and its colonies. In 1880 he coined the term <i><a href="/wiki/Francophonie" title="Francophonie">Francophonie</a></i> (the '
# b'community of French speakers) as a means of classification of peoples of the world, determined by the language they spoke. While'
# b' this term did not appear in dictionaries until 1930, it has become more important since the late 20th century as part of the co'
# b'nceptual rethinking of cultures and geography. This photograph of Reclus was taken by the French photographer <a href="/wiki/Nad'
# b'ar" title="Nadar">Nadar</a> in 1889.\n</p>\n<p style="text-align:left;"><small>Photograph credit: <a href="/wiki/Nadar" title="Nad'
# b'ar">Nadar</a>; restored by <a href="/wiki/User:Jebulon" title="User:Jebulon">Jebulon</a></small></p>\n<div class="potd-recent" st'
# b'yle="text-align:right;">\nRecently featured: <div class="hlist hlist-separated inline">\n<ul><li><a href="/wiki/Template:POTD/2022'
# b'-09-21" title="Template:POTD/2022-09-21"><i>Pantala flavescens</i></a></li>\n<li><a href="/wiki/Template:POTD/2022-09-20" title="'
# b'Template:POTD/2022-09-20"><i>Lunch atop a Skyscraper</i></a></li>\n<li><a href="/wiki/Template:POTD/2022-09-19" title="Template:P'
# b'OTD/2022-09-19">Women in World War&#160;II</a></li></ul>\n</div></div>\n<div class="hlist hlist-separated potd-footer noprint" sty'
# b'le="text-align:right;">\n<ul><li><b><a href="/wiki/Wikipedia:Picture_of_the_day/Archive" title="Wikipedia:Picture of the day/Arch'
# b'ive">Archive</a></b></li>\n<li><b><a href="/wiki/Wikipedia:Featured_pictures" title="Wikipedia:Featured pictures">More featured p'
# b'ictures</a></b></li></ul>\n</div>\n</td></tr></tbody></table></div>\n</div>\n<div id="mp-bottom" class="mp-box">\n<h2 id="mp-other" c'
# b'lass="mp-h2"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>\n<div id="mp-other-cont'
# b'ent">\n<ul><li><b><a href="/wiki/Wikipedia:Community_portal" title="Wikipedia:Community portal">Community portal</a></b> \xe2\x80\x93 The '
# b'central hub for editors, with resources, links, tasks, and announcements.</li>\n<li><b><a href="/wiki/Wikipedia:Village_pump" tit'
# b'le="Wikipedia:Village pump">Village pump</a></b> \xe2\x80\x93 Forum for discussions about Wikipedia itself, including policies and techni'
# b'cal issues.</li>\n<li><b><a href="/wiki/Wikipedia:News" title="Wikipedia:News">Site news</a></b> \xe2\x80\x93 Sources of news about Wikipe'
# b'dia and the broader Wikimedia movement.</li>\n<li><b><a href="/wiki/Wikipedia:Teahouse" title="Wikipedia:Teahouse">Teahouse</a></'
# b'b> \xe2\x80\x93 Ask basic questions about using or editing Wikipedia.</li>\n<li><b><a href="/wiki/Wikipedia:Help_desk" title="Wikipedia:He'
# b'lp desk">Help desk</a></b> \xe2\x80\x93 Ask questions about using or editing Wikipedia.</li>\n<li><b><a href="/wiki/Wikipedia:Reference_de'
# b'sk" title="Wikipedia:Reference desk">Reference desk</a></b> \xe2\x80\x93 Ask research questions about encyclopedic topics.</li>\n<li><b><a'
# b' href="/wiki/Wikipedia:Contents/Portals" title="Wikipedia:Contents/Portals">Content portals</a></b> \xe2\x80\x93 A unique way to navigate'
# b' the encyclopedia.</li></ul>\n</div>\n<h2 id="mp-sister" class="mp-h2"><span id="Wikipedia.27s_sister_projects"></span><span class'
# b'="mw-headline" id="Wikipedia\'s_sister_projects">Wikipedia\'s sister projects</span></h2>\n<div id="mp-sister-content"><style data-'
# b'mw-deduplicate="TemplateStyles:r1007624485">.mw-parser-output #sister-projects-list{display:flex;flex-wrap:wrap}.mw-parser-outpu'
# b't #sister-projects-list li{display:inline-block}.mw-parser-output #sister-projects-list li span{font-weight:bold}.mw-parser-outp'
# b'ut #sister-projects-list li>div{display:inline-block;vertical-align:middle;padding:6px 4px}.mw-parser-output #sister-projects-li'
# b'st li>div:first-child{text-align:center}@media(min-width:360px){.mw-parser-output #sister-projects-list li{width:33%;min-width:2'
# b'0em;white-space:nowrap;flex:1 0 25%}.mw-parser-output #sister-projects-list li>div:first-child{min-width:50px}}</style>\n<p>Wikip'
# b'edia is written by volunteer editors and hosted by the <a href="/wiki/Wikimedia_Foundation" title="Wikimedia Foundation">Wikimed'
# b'ia Foundation</a>, a non-profit organization that also hosts a range of other volunteer <a href="https://wikimediafoundation.org'
# b'/our-work/wikimedia-projects/" class="extiw" title="foundationsite:our-work/wikimedia-projects/">projects</a>:\n</p>\n<div class="'
# b'plainlist">\n<ul id="sister-projects-list">\n<li>\n  <div><a href="https://commons.wikimedia.org/wiki/" title="Commons"><img alt="C'
# b'ommons logo" src="//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/31px-Commons-logo.svg.png" decoding="async" wi'
# b'dth="31" height="42" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/47px-Commons-logo.svg.png 1.5x, //u'
# b'pload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/62px-Commons-logo.svg.png 2x" data-file-width="1024" data-file-heig'
# b'ht="1376" /></a></div>\n  <div><span><a href="https://commons.wikimedia.org/wiki/" class="extiw" title="c:">Commons</a></span><br'
# b' />Free media repository</div>\n</li>\n<li>\n  <div><a href="https://www.mediawiki.org/wiki/" title="MediaWiki"><img alt="MediaWiki'
# b' logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a6/MediaWiki-2020-icon.svg/35px-MediaWiki-2020-icon.svg.png" decodi'
# b'ng="async" width="35" height="35" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a6/MediaWiki-2020-icon.svg/53px-Media'
# b'Wiki-2020-icon.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a6/MediaWiki-2020-icon.svg/70px-MediaWiki-2020-ico'
# b'n.svg.png 2x" data-file-width="100" data-file-height="100" /></a></div>\n  <div><span><a href="https://www.mediawiki.org/wiki/" c'
# b'lass="extiw" title="mw:">MediaWiki</a></span><br />Wiki software development</div>\n</li>\n<li>\n  <div><a href="https://meta.wikim'
# b'edia.org/wiki/" title="Meta-Wiki"><img alt="Meta-Wiki logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/75/Wikimedia_C'
# b'ommunity_Logo.svg/35px-Wikimedia_Community_Logo.svg.png" decoding="async" width="35" height="35" srcset="//upload.wikimedia.org/'
# b'wikipedia/commons/thumb/7/75/Wikimedia_Community_Logo.svg/53px-Wikimedia_Community_Logo.svg.png 1.5x, //upload.wikimedia.org/wik'
# b'ipedia/commons/thumb/7/75/Wikimedia_Community_Logo.svg/70px-Wikimedia_Community_Logo.svg.png 2x" data-file-width="900" data-file'
# b'-height="900" /></a></div>\n  <div><span><a href="https://meta.wikimedia.org/wiki/" class="extiw" title="m:">Meta-Wiki</a></span>'
# b'<br />Wikimedia project coordination</div>\n</li>\n<li>\n  <div><a href="https://en.wikibooks.org/wiki/" title="Wikibooks"><img alt'
# b'="Wikibooks logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikibooks-logo.svg/35px-Wikibooks-logo.svg.png" decod'
# b'ing="async" width="35" height="35" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikibooks-logo.svg/53px-Wikibooks'
# b'-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikibooks-logo.svg/70px-Wikibooks-logo.svg.png 2x" data-'
# b'file-width="300" data-file-height="300" /></a></div>\n  <div><span><a href="https://en.wikibooks.org/wiki/" class="extiw" title="'
# b'b:">Wikibooks</a></span><br />Free textbooks and manuals</div>\n</li>\n<li>\n  <div><a href="https://www.wikidata.org/wiki/" title='
# b'"Wikidata"><img alt="Wikidata logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/47px-Wikidata-log'
# b'o.svg.png" decoding="async" width="47" height="26" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg'
# b'/71px-Wikidata-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/94px-Wikidata-logo.svg.p'
# b'ng 2x" data-file-width="1050" data-file-height="590" /></a></div>\n  <div><span><a href="https://www.wikidata.org/wiki/" class="e'
# b'xtiw" title="d:">Wikidata</a></span><br />Free knowledge base</div>\n</li>\n<li>\n  <div><a href="https://en.wikinews.org/wiki/" ti'
# b'tle="Wikinews"><img alt="Wikinews logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews'
# b'-logo.svg.png" decoding="async" width="51" height="28" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo'
# b'.svg/77px-Wikinews-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/102px-Wikinews-logo.'
# b'svg.png 2x" data-file-width="759" data-file-height="415" /></a></div>\n  <div><span><a href="https://en.wikinews.org/wiki/" class'
# b'="extiw" title="n:">Wikinews</a></span><br />Free-content news</div>\n</li>\n<li>\n  <div><a href="https://en.wikiquote.org/wiki/" '
# b'title="Wikiquote"><img alt="Wikiquote logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/35px-Wik'
# b'iquote-logo.svg.png" decoding="async" width="35" height="41" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquo'
# b'te-logo.svg/53px-Wikiquote-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/70px-Wikiqu'
# b'ote-logo.svg.png 2x" data-file-width="300" data-file-height="355" /></a></div>\n  <div><span><a href="https://en.wikiquote.org/wi'
# b'ki/" class="extiw" title="q:">Wikiquote</a></span><br />Collection of quotations</div>\n</li>\n<li>\n  <div><a href="https://en.wik'
# b'isource.org/wiki/" title="Wikisource"><img alt="Wikisource logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikiso'
# b'urce-logo.svg/35px-Wikisource-logo.svg.png" decoding="async" width="35" height="37" srcset="//upload.wikimedia.org/wikipedia/com'
# b'mons/thumb/4/4c/Wikisource-logo.svg/53px-Wikisource-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikis'
# b'ource-logo.svg/70px-Wikisource-logo.svg.png 2x" data-file-width="410" data-file-height="430" /></a></div>\n  <div><span><a href="'
# b'https://en.wikisource.org/wiki/" class="extiw" title="s:">Wikisource</a></span><br />Free-content library</div>\n</li>\n<li>\n  <di'
# b'v><a href="https://species.wikimedia.org/wiki/" title="Wikispecies"><img alt="Wikispecies logo" src="//upload.wikimedia.org/wiki'
# b'pedia/commons/thumb/d/df/Wikispecies-logo.svg/35px-Wikispecies-logo.svg.png" decoding="async" width="35" height="41" srcset="//u'
# b'pload.wikimedia.org/wikipedia/commons/thumb/d/df/Wikispecies-logo.svg/53px-Wikispecies-logo.svg.png 1.5x, //upload.wikimedia.org'
# b'/wikipedia/commons/thumb/d/df/Wikispecies-logo.svg/70px-Wikispecies-logo.svg.png 2x" data-file-width="941" data-file-height="110'
# b'3" /></a></div>\n  <div><span><a href="https://species.wikimedia.org/wiki/" class="extiw" title="species:">Wikispecies</a></span>'
# b'<br />Directory of species</div>\n</li>\n<li>\n  <div><a href="https://en.wikiversity.org/wiki/" title="Wikiversity"><img alt="Wiki'
# b'versity logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Wikiversity_logo_2017.svg/41px-Wikiversity_logo_2017.svg.'
# b'png" decoding="async" width="41" height="34" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Wikiversity_logo_2017.s'
# b'vg/62px-Wikiversity_logo_2017.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Wikiversity_logo_2017.svg/82px-W'
# b'ikiversity_logo_2017.svg.png 2x" data-file-width="626" data-file-height="512" /></a></div>\n  <div><span><a href="https://en.wiki'
# b'versity.org/wiki/" class="extiw" title="v:">Wikiversity</a></span><br />Free learning tools</div>\n</li>\n<li>\n  <div><a href="htt'
# b'ps://en.wikivoyage.org/wiki/" title="Wikivoyage"><img alt="Wikivoyage logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/'
# b'd/dd/Wikivoyage-Logo-v3-icon.svg/35px-Wikivoyage-Logo-v3-icon.svg.png" decoding="async" width="35" height="35" srcset="//upload.'
# b'wikimedia.org/wikipedia/commons/thumb/d/dd/Wikivoyage-Logo-v3-icon.svg/53px-Wikivoyage-Logo-v3-icon.svg.png 1.5x, //upload.wikim'
# b'edia.org/wikipedia/commons/thumb/d/dd/Wikivoyage-Logo-v3-icon.svg/70px-Wikivoyage-Logo-v3-icon.svg.png 2x" data-file-width="193"'
# b' data-file-height="193" /></a></div>\n  <div><span><a href="https://en.wikivoyage.org/wiki/" class="extiw" title="voy:">Wikivoyag'
# b'e</a></span><br />Free travel guide</div>\n</li>\n<li>\n  <div><a href="https://en.wiktionary.org/wiki/" title="Wiktionary"><img al'
# b't="Wiktionary logo" src="//upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/35px-Wiktionary-logo-v2.svg.png" '
# b'decoding="async" width="35" height="35" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/53px-Wikti'
# b'onary-logo-v2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/70px-Wiktionary-logo-v2.svg.pn'
# b'g 2x" data-file-width="391" data-file-height="391" /></a></div>\n  <div><span><a href="https://en.wiktionary.org/wiki/" class="ex'
# b'tiw" title="wikt:">Wiktionary</a></span><br />Dictionary and thesaurus</div>\n</li>\n</ul>\n</div></div>\n<h2 id="mp-lang" class="mp'
# b'-h2"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>\n<div><style data-mw-deduplicate="Templat'
# b'eStyles:r997272951">.mw-parser-output .wikipedia-languages-complete{font-weight:bold}.mw-parser-output .wikipedia-languages ul{m'
# b'argin-left:0}.mw-parser-output .wikipedia-languages ul a{white-space:nowrap}.mw-parser-output .wikipedia-languages>ul{list-style'
# b':none;text-align:center;clear:both}.mw-parser-output .wikipedia-languages-count-container{width:90%;display:flex;justify-content'
# b':center;padding-top:1em;margin:0 auto}.mw-parser-output .wikipedia-languages-prettybars{width:100%;height:1px;margin:0.5em 0;bac'
# b'kground-color:#c8ccd1;flex-shrink:1;align-self:center}.mw-parser-output .wikipedia-languages-count{padding:0 1em;white-space:now'
# b'rap}</style>\n<div class="wikipedia-languages nourlexpansion">\n<p>This Wikipedia is written in <a href="/wiki/English_language" t'
# b'itle="English language">English</a>. Many <a href="https://meta.wikimedia.org/wiki/List_of_Wikipedias" class="extiw" title="meta'
# b':List of Wikipedias">other Wikipedias are available</a>; some of the largest are listed below.\n</p>\n<ul class="plainlinks">\n<li>'
# b'\n  <div class="wikipedia-languages-count-container">\n    <div class="wikipedia-languages-prettybars"></div>\n    <div role="headi'
# b'ng" class="wikipedia-languages-count">1,000,000+ articles</div>\n    <div class="wikipedia-languages-prettybars"></div>\n  </div>\n'
# b'  <ul class="wikipedia-languages-langs hlist hlist-separated inline">\n    <li><a class="external text" href="https://ar.wikipedi'
# b'a.org/wiki/"><span class="autonym" title="Arabic (ar:)" lang="ar">\xd8\xa7\xd9\x84\xd8\xb9\xd8\xb1\xd8\xa8\xd9\x8a\xd8\xa9</span></a></li>\n    <li><a class="external text'
# b'" href="https://de.wikipedia.org/wiki/"><span class="autonym" title="German (de:)" lang="de">Deutsch</span></a></li>\n    <li><a '
# b'class="external text" href="https://es.wikipedia.org/wiki/"><span class="autonym" title="Spanish (es:)" lang="es">Espa\xc3\xb1ol</span'
# b'></a></li>\n    <li><a class="external text" href="https://fr.wikipedia.org/wiki/"><span class="autonym" title="French (fr:)" lan'
# b'g="fr">Fran\xc3\xa7ais</span></a></li>\n    <li><a class="external text" href="https://it.wikipedia.org/wiki/"><span class="autonym" ti'
# b'tle="Italian (it:)" lang="it">Italiano</span></a></li>\n    <li><a class="external text" href="https://nl.wikipedia.org/wiki/"><s'
# b'pan class="autonym" title="Dutch (nl:)" lang="nl">Nederlands</span></a></li>\n    <li><a class="external text" href="https://ja.w'
# b'ikipedia.org/wiki/"><span class="autonym" title="Japanese (ja:)" lang="ja">\xe6\x97\xa5\xe6\x9c\xac\xe8\xaa\x9e</span></a></li>\n    <li><a class="external '
# b'text" href="https://pl.wikipedia.org/wiki/"><span class="autonym" title="Polish (pl:)" lang="pl">Polski</span></a></li>\n    <li>'
# b'<a class="external text" href="https://pt.wikipedia.org/wiki/"><span class="autonym" title="Portuguese (pt:)" lang="pt">Portugu\xc3'
# b'\xaas</span></a></li>\n    <li><a class="external text" href="https://ru.wikipedia.org/wiki/"><span class="autonym" title="Russian ('
# b'ru:)" lang="ru">\xd0\xa0\xd1\x83\xd1\x81\xd1\x81\xd0\xba\xd0\xb8\xd0\xb9</span></a></li>\n    <li><a class="external text" href="https://sv.wikipedia.org/wiki/"><span clas'
# b's="autonym" title="Swedish (sv:)" lang="sv">Svenska</span></a></li>\n    <li><a class="external text" href="https://uk.wikipedia.'
# b'org/wiki/"><span class="autonym" title="Ukrainian (uk:)" lang="uk">\xd0\xa3\xd0\xba\xd1\x80\xd0\xb0\xd1\x97\xd0\xbd\xd1\x81\xd1\x8c\xd0\xba\xd0\xb0</span></a></li>\n    <li><a class="extern'
# b'al text" href="https://vi.wikipedia.org/wiki/"><span class="autonym" title="Vietnamese (vi:)" lang="vi">Ti\xe1\xba\xbfng Vi\xe1\xbb\x87t</span></a'
# b'></li>\n    <li><a class="external text" href="https://zh.wikipedia.org/wiki/"><span class="autonym" title="Chinese (zh:)" lang="'
# b'zh">\xe4\xb8\xad\xe6\x96\x87</span></a></li>\n  </ul>\n</li>\n<li>\n  <div class="wikipedia-languages-count-container">\n    <div class="wikipedia-lang'
# b'uages-prettybars"></div>\n    <div role="heading" class="wikipedia-languages-count">250,000+ articles</div>\n    <div class="wikip'
# b'edia-languages-prettybars"></div>\n  </div>\n  <ul class="wikipedia-languages-langs hlist hlist-separated inline">\n    <li><a clas'
# b's="external text" href="https://id.wikipedia.org/wiki/"><span class="autonym" title="Indonesian (id:)" lang="id">Bahasa Indonesi'
# b'a</span></a></li>\n    <li><a class="external text" href="https://ms.wikipedia.org/wiki/"><span class="autonym" title="Malay (ms:'
# b')" lang="ms">Bahasa Melayu</span></a></li>\n    <li><a class="external text" href="https://zh-min-nan.wikipedia.org/wiki/"><span '
# b'class="autonym" title="Min Nan Chinese (nan:)" lang="nan">B\xc3\xa2n-l\xc3\xa2m-g\xc3\xba</span></a></li>\n    <li><a class="external text" href="h'
# b'ttps://bg.wikipedia.org/wiki/"><span class="autonym" title="Bulgarian (bg:)" lang="bg">\xd0\x91\xd1\x8a\xd0\xbb\xd0\xb3\xd0\xb0\xd1\x80\xd1\x81\xd0\xba\xd0\xb8</span></a></li>\n    <l'
# ...
# b'><span>Bosanski</span></a></li><li class="interlanguage-link interwiki-ca mw-list-item"><a href="https://ca.wikipedia.org/wiki/"'
# b' title="Catalan" lang="ca" hreflang="ca" class="interlanguage-link-target"><span>Catal\xc3\xa0</span></a></li><li class="interlanguage'
# b'-link interwiki-cs mw-list-item"><a href="https://cs.wikipedia.org/wiki/" title="Czech" lang="cs" hreflang="cs" class="interlang'
# b'uage-link-target"><span>\xc4\x8ce\xc5\xa1tina</span></a></li><li class="interlanguage-link interwiki-da mw-list-item"><a href="https://da.wi'
# b'kipedia.org/wiki/" title="Danish" lang="da" hreflang="da" class="interlanguage-link-target"><span>Dansk</span></a></li><li class'
# b'="interlanguage-link interwiki-de mw-list-item"><a href="https://de.wikipedia.org/wiki/" title="German" lang="de" hreflang="de" '
# b'class="interlanguage-link-target"><span>Deutsch</span></a></li><li class="interlanguage-link interwiki-et mw-list-item"><a href='
# b'"https://et.wikipedia.org/wiki/" title="Estonian" lang="et" hreflang="et" class="interlanguage-link-target"><span>Eesti</span></'
# b'a></li><li class="interlanguage-link interwiki-el mw-list-item"><a href="https://el.wikipedia.org/wiki/" title="Greek" lang="el"'
# b' hreflang="el" class="interlanguage-link-target"><span>\xce\x95\xce\xbb\xce\xbb\xce\xb7\xce\xbd\xce\xb9\xce\xba\xce\xac</span></a></li><li class="interlanguage-link interwiki-e'
# b's mw-list-item"><a href="https://es.wikipedia.org/wiki/" title="Spanish" lang="es" hreflang="es" class="interlanguage-link-targe'
# b't"><span>Espa\xc3\xb1ol</span></a></li><li class="interlanguage-link interwiki-eo mw-list-item"><a href="https://eo.wikipedia.org/wiki'
# b'/" title="Esperanto" lang="eo" hreflang="eo" class="interlanguage-link-target"><span>Esperanto</span></a></li><li class="interla'
# b'nguage-link interwiki-eu mw-list-item"><a href="https://eu.wikipedia.org/wiki/" title="Basque" lang="eu" hreflang="eu" class="in'
# b'terlanguage-link-target"><span>Euskara</span></a></li><li class="interlanguage-link interwiki-fa mw-list-item"><a href="https://'
# b'fa.wikipedia.org/wiki/" title="Persian" lang="fa" hreflang="fa" class="interlanguage-link-target"><span>\xd9\x81\xd8\xa7\xd8\xb1\xd8\xb3\xdb\x8c</span></a></l'
# b'i><li class="interlanguage-link interwiki-fr mw-list-item"><a href="https://fr.wikipedia.org/wiki/" title="French" lang="fr" hre'
# b'flang="fr" class="interlanguage-link-target"><span>Fran\xc3\xa7ais</span></a></li><li class="interlanguage-link interwiki-gl mw-list-i'
# b'tem"><a href="https://gl.wikipedia.org/wiki/" title="Galician" lang="gl" hreflang="gl" class="interlanguage-link-target"><span>G'
# b'alego</span></a></li><li class="interlanguage-link interwiki-ko mw-list-item"><a href="https://ko.wikipedia.org/wiki/" title="Ko'
# b'rean" lang="ko" hreflang="ko" class="interlanguage-link-target"><span>\xed\x95\x9c\xea\xb5\xad\xec\x96\xb4</span></a></li><li class="interlanguage-link int'
# b'erwiki-hr mw-list-item"><a href="https://hr.wikipedia.org/wiki/" title="Croatian" lang="hr" hreflang="hr" class="interlanguage-l'
# b'ink-target"><span>Hrvatski</span></a></li><li class="interlanguage-link interwiki-id mw-list-item"><a href="https://id.wikipedia'
# b'.org/wiki/" title="Indonesian" lang="id" hreflang="id" class="interlanguage-link-target"><span>Bahasa Indonesia</span></a></li><'
# b'li class="interlanguage-link interwiki-it mw-list-item"><a href="https://it.wikipedia.org/wiki/" title="Italian" lang="it" hrefl'
# b'ang="it" class="interlanguage-link-target"><span>Italiano</span></a></li><li class="interlanguage-link interwiki-he mw-list-item'
# b'"><a href="https://he.wikipedia.org/wiki/" title="Hebrew" lang="he" hreflang="he" class="interlanguage-link-target"><span>\xd7\xa2\xd7\x91\xd7\xa8'
# b'\xd7\x99\xd7\xaa</span></a></li><li class="interlanguage-link interwiki-ka mw-list-item"><a href="https://ka.wikipedia.org/wiki/" title="Geo'
# b'rgian" lang="ka" hreflang="ka" class="interlanguage-link-target"><span>\xe1\x83\xa5\xe1\x83\x90\xe1\x83\xa0\xe1\x83\x97\xe1\x83\xa3\xe1\x83\x9a\xe1\x83\x98</span></a></li><li class="interlang'
# b'uage-link interwiki-lv mw-list-item"><a href="https://lv.wikipedia.org/wiki/" title="Latvian" lang="lv" hreflang="lv" class="int'
# b'erlanguage-link-target"><span>Latvie\xc5\xa1u</span></a></li><li class="interlanguage-link interwiki-lt mw-list-item"><a href="https:/'
# b'/lt.wikipedia.org/wiki/" title="Lithuanian" lang="lt" hreflang="lt" class="interlanguage-link-target"><span>Lietuvi\xc5\xb3</span></a>'
# b'</li><li class="interlanguage-link interwiki-hu mw-list-item"><a href="https://hu.wikipedia.org/wiki/" title="Hungarian" lang="h'
# b'u" hreflang="hu" class="interlanguage-link-target"><span>Magyar</span></a></li><li class="interlanguage-link interwiki-mk mw-lis'
# b't-item"><a href="https://mk.wikipedia.org/wiki/" title="Macedonian" lang="mk" hreflang="mk" class="interlanguage-link-target"><s'
# b'pan>\xd0\x9c\xd0\xb0\xd0\xba\xd0\xb5\xd0\xb4\xd0\xbe\xd0\xbd\xd1\x81\xd0\xba\xd0\xb8</span></a></li><li class="interlanguage-link interwiki-ms mw-list-item"><a href="https://ms.wikipedia.o'
# b'rg/wiki/" title="Malay" lang="ms" hreflang="ms" class="interlanguage-link-target"><span>Bahasa Melayu</span></a></li><li class="'
# b'interlanguage-link interwiki-nl mw-list-item"><a href="https://nl.wikipedia.org/wiki/" title="Dutch" lang="nl" hreflang="nl" cla'
# b'ss="interlanguage-link-target"><span>Nederlands</span></a></li><li class="interlanguage-link interwiki-ja mw-list-item"><a href='
# b'"https://ja.wikipedia.org/wiki/" title="Japanese" lang="ja" hreflang="ja" class="interlanguage-link-target"><span>\xe6\x97\xa5\xe6\x9c\xac\xe8\xaa\x9e</spa'
# b'n></a></li><li class="interlanguage-link interwiki-no mw-list-item"><a href="https://no.wikipedia.org/wiki/" title="Norwegian Bo'
# b'km\xc3\xa5l" lang="nb" hreflang="nb" class="interlanguage-link-target"><span>Norsk bokm\xc3\xa5l</span></a></li><li class="interlanguage-lin'
# b'k interwiki-nn mw-list-item"><a href="https://nn.wikipedia.org/wiki/" title="Norwegian Nynorsk" lang="nn" hreflang="nn" class="i'
# b'nterlanguage-link-target"><span>Norsk nynorsk</span></a></li><li class="interlanguage-link interwiki-pl mw-list-item"><a href="h'
# b'ttps://pl.wikipedia.org/wiki/" title="Polish" lang="pl" hreflang="pl" class="interlanguage-link-target"><span>Polski</span></a><'
# b'/li><li class="interlanguage-link interwiki-pt mw-list-item"><a href="https://pt.wikipedia.org/wiki/" title="Portuguese" lang="p'
# b't" hreflang="pt" class="interlanguage-link-target"><span>Portugu\xc3\xaas</span></a></li><li class="interlanguage-link interwiki-ro mw'
# b'-list-item"><a href="https://ro.wikipedia.org/wiki/" title="Romanian" lang="ro" hreflang="ro" class="interlanguage-link-target">'
# b'<span>Rom\xc3\xa2n\xc4\x83</span></a></li><li class="interlanguage-link interwiki-ru mw-list-item"><a href="https://ru.wikipedia.org/wiki/" '
# b'title="Russian" lang="ru" hreflang="ru" class="interlanguage-link-target"><span>\xd0\xa0\xd1\x83\xd1\x81\xd1\x81\xd0\xba\xd0\xb8\xd0\xb9</span></a></li><li class="interla'
# b'nguage-link interwiki-simple mw-list-item"><a href="https://simple.wikipedia.org/wiki/" title="Simple English" lang="en-simple" '
# b'hreflang="en-simple" class="interlanguage-link-target"><span>Simple English</span></a></li><li class="interlanguage-link interwi'
# b'ki-sk mw-list-item"><a href="https://sk.wikipedia.org/wiki/" title="Slovak" lang="sk" hreflang="sk" class="interlanguage-link-ta'
# b'rget"><span>Sloven\xc4\x8dina</span></a></li><li class="interlanguage-link interwiki-sl mw-list-item"><a href="https://sl.wikipedia.or'
# b'g/wiki/" title="Slovenian" lang="sl" hreflang="sl" class="interlanguage-link-target"><span>Sloven\xc5\xa1\xc4\x8dina</span></a></li><li clas'
# b's="interlanguage-link interwiki-sr mw-list-item"><a href="https://sr.wikipedia.org/wiki/" title="Serbian" lang="sr" hreflang="sr'
# b'" class="interlanguage-link-target"><span>\xd0\xa1\xd1\x80\xd0\xbf\xd1\x81\xd0\xba\xd0\xb8 / srpski</span></a></li><li class="interlanguage-link interwiki-sh mw-lis'
# b't-item"><a href="https://sh.wikipedia.org/wiki/" title="Serbo-Croatian" lang="sh" hreflang="sh" class="interlanguage-link-target'
# b'"><span>Srpskohrvatski / \xd1\x81\xd1\x80\xd0\xbf\xd1\x81\xd0\xba\xd0\xbe\xd1\x85\xd1\x80\xd0\xb2\xd0\xb0\xd1\x82\xd1\x81\xd0\xba\xd0\xb8</span></a></li><li class="interlanguage-link interwiki-fi mw-list-item"><a'
# b' href="https://fi.wikipedia.org/wiki/" title="Finnish" lang="fi" hreflang="fi" class="interlanguage-link-target"><span>Suomi</sp'
# b'an></a></li><li class="interlanguage-link interwiki-sv mw-list-item"><a href="https://sv.wikipedia.org/wiki/" title="Swedish" la'
# b'ng="sv" hreflang="sv" class="interlanguage-link-target"><span>Svenska</span></a></li><li class="interlanguage-link interwiki-th '
# b'mw-list-item"><a href="https://th.wikipedia.org/wiki/" title="Thai" lang="th" hreflang="th" class="interlanguage-link-target"><s'
# b'pan>\xe0\xb9\x84\xe0\xb8\x97\xe0\xb8\xa2</span></a></li><li class="interlanguage-link interwiki-tr mw-list-item"><a href="https://tr.wikipedia.org/wiki/" t'
# b'itle="Turkish" lang="tr" hreflang="tr" class="interlanguage-link-target"><span>T\xc3\xbcrk\xc3\xa7e</span></a></li><li class="interlanguage-'
# b'link interwiki-uk mw-list-item"><a href="https://uk.wikipedia.org/wiki/" title="Ukrainian" lang="uk" hreflang="uk" class="interl'
# b'anguage-link-target"><span>\xd0\xa3\xd0\xba\xd1\x80\xd0\xb0\xd1\x97\xd0\xbd\xd1\x81\xd1\x8c\xd0\xba\xd0\xb0</span></a></li><li class="interlanguage-link interwiki-vi mw-list-item"><a href='
# b'"https://vi.wikipedia.org/wiki/" title="Vietnamese" lang="vi" hreflang="vi" class="interlanguage-link-target"><span>Ti\xe1\xba\xbfng Vi\xe1\xbb'
# b'\x87t</span></a></li><li class="interlanguage-link interwiki-zh mw-list-item"><a href="https://zh.wikipedia.org/wiki/" title="Chine'
# b'se" lang="zh" hreflang="zh" class="interlanguage-link-target"><span>\xe4\xb8\xad\xe6\x96\x87</span></a></li></ul>\n\t\t\n\t</div>\n</nav>\n\n</div>\n\n</div'
# b'>\n\n<footer id="footer" class="mw-footer" role="contentinfo" >\n\t<ul id="footer-info">\n\t<li id="footer-info-lastmod"> This page wa'
# b's last edited on 2 September 2022, at 13:05<span class="anonymous-show">&#160;(UTC)</span>.</li>\n\t<li id="footer-info-copyright"'
# b'>Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-Share'
# b'Alike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License 3.0</a><a rel="license" href="//creativecommons.org/'
# b'licenses/by-sa/3.0/" style="display:none;"></a>;\nadditional terms may apply.  By using this site, you agree to the <a href="//fo'
# b'undation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy '
# b'Policy</a>. Wikipedia\xc2\xae is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>'
# b', a non-profit organization.</li>\n</ul>\n\n\t<ul id="footer-places">\n\t<li id="footer-places-privacy"><a href="https://foundation.wi'
# b'kimedia.org/wiki/Privacy_policy">Privacy policy</a></li>\n\t<li id="footer-places-about"><a href="/wiki/Wikipedia:About">About Wik'
# b'ipedia</a></li>\n\t<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer">Disclaimers</a></li>\n\t<li id="fo'
# b'oter-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>\n\t<li id="footer-places-mo'
# b'bileview"><a href="//en.m.wikipedia.org/w/index.php?title=Main_Page&amp;mobileaction=toggle_view_mobile" class="noprint stopMobi'
# b'leRedirectToggle">Mobile view</a></li>\n\t<li id="footer-places-developers"><a href="https://developer.wikimedia.org">Developers</'
# b'a></li>\n\t<li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>\n\t<li id="'
# b'footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>\n</ul>\n'
# b'\n\t<ul id="footer-icons" class="noprint">\n\t<li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img src="/sta'
# b'tic/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wiki'
# b'media-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation" loading="lazy" /></a></li>\n\t<li id="footer-poweredbyic'
# b'o"><a href="https://www.mediawiki.org/"><img src="/static/images/footer/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki'
# b'" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" wi'
# b'dth="88" height="31" loading="lazy"/></a></li>\n</ul>\n\n</footer>\n\n<script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wg'
# b'PageParseReport":{"limitreport":{"cputime":"0.252","walltime":"0.384","ppvisitednodes":{"value":4036,"limit":1000000},"postexpan'
# b'dincludesize":{"value":126123,"limit":2097152},"templateargumentsize":{"value":11393,"limit":2097152},"expansiondepth":{"value":'
# b'20,"limit":100},"expensivefunctioncount":{"value":14,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value"'
# b':3979,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  268.942      1 -total"," 40.69%  1'
# b'09.430      1 Wikipedia:Main_Page/Tomorrow"," 25.43%   68.391      8 Template:Main_page_image"," 17.40%   46.789      8 Template'
# b':Str_number/trim"," 16.57%   44.560      1 Wikipedia:Today\'s_featured_article/September_22,_2022"," 15.71%   42.258      1 Templ'
# b'ate:Did_you_know/Queue/7"," 14.37%   38.639      1 Wikipedia:Selected_anniversaries/September_22"," 13.38%   35.987      2 Templ'
# b'ate:Wikipedia_languages"," 12.62%   33.933      1 Template:DYKbotdo"," 12.27%   33.004      1 Template:Main_page_image/TFA"]},"s'
# b'cribunto":{"limitreport-timeusage":{"value":"0.051","limit":"10.000"},"limitreport-memusage":{"value":2112883,"limit":52428800}}'
# b',"cachereport":{"origin":"mw2325","timestamp":"20220922205804","ttl":3600,"transientcontent":true}}});});</script>\n<script type='
# b'"application/ld+json">{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Main Page","url":"https:\\/\\/en.wikipedia.org\\'
# b'/wiki\\/Main_Page","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q5296","mainEntity":"http:\\/\\/www.wikidata.org\\/entity\\/Q5296","a'
# b'uthor":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedi'
# b'a Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png"}},"da'
# b'tePublished":"2002-01-26T15:28:12Z","dateModified":"2022-09-02T13:05:06Z","image":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/co'
# b'mmons\\/0\\/07\\/Portland_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg","headline":"Wikimedia project page"}</scrip'
# b't><script type="application/ld+json">{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Main Page","url":"https:\\/\\/en'
# b'.wikipedia.org\\/wiki\\/Main_Page","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q5296","mainEntity":"http:\\/\\/www.wikidata.org\\/en'
# b'tity\\/Q5296","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","'
# b'name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-goo'
# b'gpub.png"}},"datePublished":"2002-01-26T15:28:12Z","dateModified":"2022-09-02T13:05:06Z","image":"https:\\/\\/upload.wikimedia.org'
# b'\\/wikipedia\\/commons\\/0\\/07\\/Portland_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg","headline":"Wikimedia projec'
# b't page"}</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":504,"wgHostname":"mw2325"}'
# b');});</script>\n</body>\n</html>'

# %% [markdown]
# ### Exercise 2: Write a small function to check the status of web request
#
# This kind of small helper/utility functions are incredibly useful for complex projects.
#
# Start building **a habit of writing small functions to accomplish small modular tasks**, instead of writing long scripts, which are hard to debug and track.

# %%
def status_check(r):
    if r.status_code==200:
        print("Success!")
        return 1
    else:
        print("Failed!")
        return -1

# %%
status_check(response)
# Out:
# Success!
# 1

# %% [markdown]
# ### Exercise 3: Write small function to check the encoding of the web page

# %%
def encoding_check(r):
    return (r.encoding)

# %%
encoding_check(response)
# Out:
# 'UTF-8'

# %% [markdown]
# ### Exercise 4: Write a small function to decode the concents of the `response`

# %%
def decode_content(r,encoding):
    return (r.content.decode(encoding))

# %%
contents = decode_content(response,encoding_check(response))

# %% [markdown]
# #### What is the type of the contents?

# %%
type(contents)
# Out:
# str

# %%
contents
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"2905378d-a6f4-4e8c-890c-386978280edf","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1108085777,"wgRevisionId":1108085777,"wgArticleId":15580374,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["sysop"],"wgRestrictionMove":["sysop"],"wgIsMainPage":true,"wgFlaggedRevsParams":{\n"tags":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":3000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q5296","GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","skins.vector.styles.legacy":"ready",\n"ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready"};RLPAGEMODULES=["site","mediawiki.page.ready","skins.vector.legacy.js","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cskins.vector.styles.legacy&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n<meta name="generator" content="MediaWiki 1.40.0-wmf.2"/>\n<meta name="referrer" content="origin"/>\n<meta name="referrer" content="origin-when-crossorigin"/>\n<meta name="referrer" content="origin-when-cross-origin"/>\n<meta name="format-detection" content="telephone=no"/>\n<meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/0/07/Portland_Streetcar_car_023_at_west_end_of_Broadway_Bridge_in_2016.jpg/1200px-Portland_Street ...

# %% [markdown]
# #### Fantastic! Finally we got a string object. Did you see how easy it was to read text from a popular webpage like Wikipedia?

# %% [markdown]
# ### Exercise 5: Check the length of the text you got back and print some selected portions

# %%
len(contents)
# Out:
# 82523

# %%
print(contents[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"2905378d-a6f4-4e8c-890c-386978280edf","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1108085777,"wgRevisionId":1108085777,"wgArticleId":15580374,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":fals

# %%
print(contents[15000:16000])
# Out:
# /September 2022">Archive</a></b></li>
# <li><b><a href="https://lists.wikimedia.org/postorius/lists/daily-article-l.lists.wikimedia.org/" class="extiw" title="mail:daily-article-l">By email</a></b></li>
# <li><b><a href="/wiki/Wikipedia:Featured_articles" title="Wikipedia:Featured articles">More featured articles</a></b></li>
# <li><b><a href="/wiki/Wikipedia:About_Today%27s_featured_article" title="Wikipedia:About Today&#39;s featured article">About</a></b></li></ul>
# </div></div>
# <h2 id="mp-dyk-h2" class="mp-h2"><span class="mw-headline" id="Did_you_know_...">Did you know&#160;...</span></h2>
# <div id="mp-dyk" class="mp-contains-float">
# <div class="dyk-img" style="float: right; margin-left: 0.5em;">
# <div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 101px;">
# <a href="/wiki/File:San_Remo_apartments_from_Central_Park,_NYC.jpg" class="image" title="The San Remo"><img alt="The San Remo" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a1/Sa

# %% [markdown]
# ### Exercise 6: Use `BeautifulSoup` package to parse the raw HTML text more meaningfully and search for a particular text

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(contents, 'html.parser')

# %% [markdown]
# #### What is this new `soup` object?

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### Exercise 7: Can we somehow read intelligible text from this `soup` object?

# %%
txt_dump=soup.text

# %%
type(txt_dump)
# Out:
# str

# %%
len(txt_dump)
# Out:
# 8342

# %%
print(txt_dump[0:])
# Out:
# Wikipedia, the free encyclopedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Main Page
#
# From Wikipedia, the free encyclopedia
#
#
#
# Jump to navigation
# Jump to search
#
#
#
# Welcome to Wikipedia,
# the free encyclopedia that anyone can edit.
# 6,553,743 articles in English
#
#
#
#
# From today's featured article
#
#
# Portland Streetcar vehicle on the Broadway Bridge
#
# The A and B Loop is a streetcar circle route of the Portland Streetcar system in Portland, Oregon, United States. Operated by Portland Streetcar, Inc. and TriMet, it consists of two services within the Central City that travel a loop between the east and west sides of the Willamette River by crossing the Broadway Bridge (pictured) in the north and Tilikum Crossing in the south. The services connect Portland's downtown, Pearl District, Lloyd District, Central Eastside, and South Waterfront. Portland city officials considered an eastside streetcar extension upon authorizing the Central City Streetcar project in 1997. After several years of planning, the Portland Streetcar Loop Project was approved and held its groundbreaking in 2009. It opened between the Broadway Bridge and the Oregon Museum of Science and Industry on September 22, 2012. The opening of Tilikum Crossing in 2015 further extended its tracks from the museum to the South Waterfront and completed the loop. (Full article...)
#
#
# Recently featured:
# Alexander Cameron Rutherford
# A.C. Monza
# Elizabeth II
#
#
# Archive
# By email
# More featured articles
# About
#
# Did you know ...
#
#
#
# The San Remo
#
# ... that the San Remo (pictured) was once described as an "ATM for Democratic presidential campaigns" in the United States?
# ... that the shop in Cairo designed by Robert Williams for the Davies Bryan Company became a site of "pilgrimage for all Welsh travellers" to Egypt?
# ... that Pedro II of Brazil examined the signal system on the Fitchburg Cutoff?
# ... that when Francesco Lanzillotta conducted Dallapiccola's Ulisse at Oper Frankfurt in 2022, a reviewer noted that he "does not shy away from agglomerations of sound"?
# ... that in 2009, residents of Maine voted to repeal a law that would have legalized same-sex marriage?
# ... that yachting photographer Eileen Ramsay damaged many Rolleiflex cameras by attempting to take photos at water level?
# ... that "illegal operation" was a common euphemism for abortion in early-20th-century North American newspapers?
# ... that Ekuikui V was deposed as the king of Bailundo in 2021 and sentenced to six years in prison?
#
# Archive
# Start a new article
# Nominate an article
#
#
#
#
# In the news
#
#
# Jean-Luc Godard in 1968
#
# Protests in Iran following the death of Mahsa Amini leave more than 30 people dead.
# At least 100 people are killed in renewed fighting between Kyrgyzstan and Tajikistan.
# In the Swedish general election, the Sweden Democrats–Moderates–Christian Democrats–Liberals bloc wins a majority of seats in the Riksdag.
# French-Swiss filmmaker Jean-Luc Godard (pictured) dies at the age of 91.
#
# Ongoing:
# Russian invasion of Ukraine
# Recent deaths:
# Liam Holden
# Nick Holonyak
# Allan M. Siegal
# Maury Wills
# Herb Lusk
# Raju Srivastav
#
# Nominate an article
#
# On this day
#
# September 22
#
#
#
# Richard Wagner
#
# 1586 – Eighty Years' War: Spanish forces defeated an Anglo-Dutch army at the Battle of Zutphen.
# 1869 – Das Rheingold, the first of four operas in Der Ring des Nibelungen by the German composer Richard Wagner (pictured), was first performed in Munich.
# 1934 – One of Britain's worst mining accidents took place when an explosion at Gresford Colliery in Wales killed 266 men.
# 1979 – An American Vela satellite detected an unidentified flash of light near the Prince Edward Islands in the Indian Ocean, thought to be a nuclear weapons test.
# 1994 – The Nordhordland Bridge, crossing Salhusfjorden between Klauvaneset and Flatøy in Vestland, and Norway's second-longest bridge, officially opened.
# Wilhelm Keitel  (b. 1882)Norma McCorvey  (b. 1947)Aurelio López  (d. 1992)
#
# More anniversaries:
# September 21
# September 22
# September 23
#
#
# Archive
# By email
# List of days of the year
#
#
#
#
# Today's featured picture
#
#
#
#
#
#
# Onésime Reclus (22 September 1837 – 30 June 1916), was a French geographer who specialized in the relations between France and its colonies. In 1880 he coined the term Francophonie (the community of French speakers) as a means of classification of peoples of the world, determined by the language they spoke. While this term did not appear in dictionaries until 1930, it has become more important since the late 20th century as part of the conceptual rethinking of cultures and geography. This photograph of Reclus was taken by the French photographer Nadar in 1889.
#
# Photograph credit: Nadar; restored by Jebulon
#
# Recently featured:
# Pantala flavescens
# Lunch atop a Skyscraper
# Women in World War II
#
#
# Archive
# More featured pictures
#
#
#
#
# Other areas of Wikipedia
#
# Community portal – The central hub for editors, with resources, links, tasks, and announcements.
# Village pump – Forum for discussions about Wikipedia itself, including policies and technical issues.
# Site news – Sources of news about Wikipedia and the broader Wikimedia movement.
# Teahouse – Ask basic questions about using or editing Wikipedia.
# Help desk – Ask questions about using or editing Wikipedia.
# Reference desk – Ask research questions about encyclopedic topics.
# Content portals – A unique way to navigate the encyclopedia.
#
# Wikipedia's sister projects
#
# Wikipedia is written by volunteer editors and hosted by the Wikimedia Foundation, a non-profit organization that also hosts a range of other volunteer projects:
#
#
#
#
#
# CommonsFree media repository
#
#
#
# MediaWikiWiki software development
#
#
#
# Meta-WikiWikimedia project coordination
#
#
#
# WikibooksFree textbooks and manuals
#
#
#
# WikidataFree knowledge base
#
#
#
# WikinewsFree-content news
#
#
#
# WikiquoteCollection of quotations
#
#
#
# WikisourceFree-content library
#
#
#
# WikispeciesDirectory of species
#
#
#
# WikiversityFree learning tools
#
#
#
# WikivoyageFree travel guide
#
#
#
# WiktionaryDictionary and thesaurus
#
#
#
# Wikipedia languages
#
#
# This Wikipedia is written in English. Many other Wikipedias are available; some of the largest are listed below.
#
#
#
#
#
# 1,000,000+ articles
#
#
#
# العربية
# Deutsch
# Español
# Français
# Italiano
# Nederlands
# 日本語
# Polski
# Português
# Русский
# Svenska
# Українська
# Tiếng Việt
# 中文
#
#
#
#
#
# 250,000+ articles
#
#
#
# Bahasa Indonesia
# Bahasa Melayu
# Bân-lâm-gú
# Български
# Català
# Čeština
# Dansk
# Esperanto
# Euskara
# فارسی‎
# עברית
# 한국어
# Magyar
# Norsk Bokmål
# Română
# Srpski
# Srpskohrvatski
# Suomi
# Türkçe
#
#
#
#
#
# 50,000+ articles
#
#
#
# Asturianu
# বাংলা
# Bosanski
# Eesti
# Ελληνικά
# Simple English
# Galego
# Hrvatski
# Latviešu
# Lietuvių
# മലയാളം
# Македонски
# Norsk nynorsk
# Shqip
# Slovenčina
# Slovenščina
# ไทย
#
#
#
#
#
#
#
#
#
# Retrieved from "https://en.wikipedia.org/w/index.php?title=Main_Page&oldid=1108085777"
#
#
#
#
# Navigation menu
#
#
#
# Personal tools
#
#
# Not logged inTalkContributionsCreate accountLog in
#
#
#
#
#
# Namespaces
#
#
# Main PageTalk
#
#
#
#
#
# English
#
#
#
#
#
#
#
#
#
# Views
#
#
# ReadView sourceView history
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate
#
#
#
#
# Contribute
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
# Tools
#
#
# What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageWikidata item
#
#
#
#
# Print/export
#
#
# Download as PDFPrintable version
#
#
#
#
# In other projects
#
#
# Wikimedia CommonsMediaWikiMeta-WikiMultilingual WikisourceWikispeciesWikibooksWikidataWikimaniaWikinewsWikiquoteWikisourceWikiversityWikivoyageWiktionary
#
#
#
#
# Languages
#
#
# العربيةবাংলাБългарскиBosanskiCatalàČeštinaDanskDeutschEestiΕλληνικάEspañolEsperantoEuskaraفارسیFrançaisGalego한국어HrvatskiBahasa IndonesiaItalianoעבריתქართულიLatviešuLietuviųMagyarМакедонскиBahasa MelayuNederlands日本語Norsk bokmålNorsk nynorskPolskiPortuguêsRomânăРусскийSimple EnglishSlovenčinaSlovenščinaСрпски / srpskiSrpskohrvatski / српскохрватскиSuomiSvenskaไทยTürkçeУкраїнськаTiếng Việt中文
#
#
#
#
#
#
#  This page was last edited on 2 September 2022, at 13:05 (UTC).
# Text is available under the Creative Commons Attribution-ShareAlike License 3.0;
# additional terms may apply.  By using this site, you agree to the Terms of Use and Privacy Policy. Wikipedia® is a registered trademark of the Wikimedia Foundation, Inc., a non-profit organization.
#
#
# Privacy policy
# About Wikipedia
# Disclaimers
# Contact Wikipedia
# Mobile view
# Developers
# Statistics
# Cookie statement

# %% [markdown]
# ### Exercise 8: Extract the text from the section *'From today's featured article'*

# %%
# First extract the starting and end indecies of the text we are interested in
idx1=txt_dump.find("From today's featured article")
idx2=txt_dump.find("Recently featured")

# %%
print(txt_dump[idx1+len("From today's featured article"):idx2])
# Out:
# Portland Streetcar vehicle on the Broadway Bridge
#
# The A and B Loop is a streetcar circle route of the Portland Streetcar system in Portland, Oregon, United States. Operated by Portland Streetcar, Inc. and TriMet, it consists of two services within the Central City that travel a loop between the east and west sides of the Willamette River by crossing the Broadway Bridge (pictured) in the north and Tilikum Crossing in the south. The services connect Portland's downtown, Pearl District, Lloyd District, Central Eastside, and South Waterfront. Portland city officials considered an eastside streetcar extension upon authorizing the Central City Streetcar project in 1997. After several years of planning, the Portland Streetcar Loop Project was approved and held its groundbreaking in 2009. It opened between the Broadway Bridge and the Oregon Museum of Science and Industry on September 22, 2012. The opening of Tilikum Crossing in 2015 further extended its tracks from the museum to the South Waterfront and completed the loop. (Full article...)

# %% [markdown]
# ### Exercise 9: Try to extract the important historical events that happened on today's date...

# %%
idx3=txt_dump.find("On this day")

# %%
print(txt_dump[idx3+len("On this day"):idx3+len("On this day")+1000])
# Out:
# September 22
#
#
#
# Richard Wagner
#
# 1586 – Eighty Years' War: Spanish forces defeated an Anglo-Dutch army at the Battle of Zutphen.
# 1869 – Das Rheingold, the first of four operas in Der Ring des Nibelungen by the German composer Richard Wagner (pictured), was first performed in Munich.
# 1934 – One of Britain's worst mining accidents took place when an explosion at Gresford Colliery in Wales killed 266 men.
# 1979 – An American Vela satellite detected an unidentified flash of light near the Prince Edward Islands in the Indian Ocean, thought to be a nuclear weapons test.
# 1994 – The Nordhordland Bridge, crossing Salhusfjorden between Klauvaneset and Flatøy in Vestland, and Norway's second-longest bridge, officially opened.
# Wilhelm Keitel  (b. 1882)Norma McCorvey  (b. 1947)Aurelio López  (d. 1992)
#
# More anniversaries:
# September 21
# September 22
# September 23
#
#
# Archive
# By email
# List of days of the year
#
#
#
#
# Today's featured picture
#
#
#
#
#
#
# Onésime Reclus (22 September 1837 – 30 June 1916), was a Fre

# %% [markdown]
# ### Exercise 10: Use advanced BS4 technique to extract relevant text without guessing or hard coding where to look

# %%
for d in soup.find_all('div'):
        if (d.get('id')=='mp-otd'):
            for i in d.find_all('ul'):
                print(i.text)
# Out:
# 1586 – Eighty Years' War: Spanish forces defeated an Anglo-Dutch army at the Battle of Zutphen.
# 1869 – Das Rheingold, the first of four operas in Der Ring des Nibelungen by the German composer Richard Wagner (pictured), was first performed in Munich.
# 1934 – One of Britain's worst mining accidents took place when an explosion at Gresford Colliery in Wales killed 266 men.
# 1979 – An American Vela satellite detected an unidentified flash of light near the Prince Edward Islands in the Indian Ocean, thought to be a nuclear weapons test.
# 1994 – The Nordhordland Bridge, crossing Salhusfjorden between Klauvaneset and Flatøy in Vestland, and Norway's second-longest bridge, officially opened.
# Wilhelm Keitel  (b. 1882)Norma McCorvey  (b. 1947)Aurelio López  (d. 1992)
# September 21
# September 22
# September 23
# Archive
# By email
# List of days of the year

# %%
text_list=[]
for d in soup.find_all('div'):
        if (d.get('id')=='mp-otd'):
            for i in d.find_all('ul'):
                text_list.append(i.text)

# %%
len(text_list)

# %%
for i in text_list:
    print(i)
    print('-'*100)
# Out:
# 1586 – Eighty Years' War: Spanish forces defeated an Anglo-Dutch army at the Battle of Zutphen.
# 1869 – Das Rheingold, the first of four operas in Der Ring des Nibelungen by the German composer Richard Wagner (pictured), was first performed in Munich.
# 1934 – One of Britain's worst mining accidents took place when an explosion at Gresford Colliery in Wales killed 266 men.
# 1979 – An American Vela satellite detected an unidentified flash of light near the Prince Edward Islands in the Indian Ocean, thought to be a nuclear weapons test.
# 1994 – The Nordhordland Bridge, crossing Salhusfjorden between Klauvaneset and Flatøy in Vestland, and Norway's second-longest bridge, officially opened.
# ----------------------------------------------------------------------------------------------------
# Wilhelm Keitel  (b. 1882)Norma McCorvey  (b. 1947)Aurelio López  (d. 1992)
# ----------------------------------------------------------------------------------------------------
# September 21
# September 22
# September 23
# ----------------------------------------------------------------------------------------------------
# Archive
# By email
# List of days of the year
# ----------------------------------------------------------------------------------------------------

# %%
print(text_list[0])
# Out:
# 1586 – Eighty Years' War: Spanish forces defeated an Anglo-Dutch army at the Battle of Zutphen.
# 1869 – Das Rheingold, the first of four operas in Der Ring des Nibelungen by the German composer Richard Wagner (pictured), was first performed in Munich.
# 1934 – One of Britain's worst mining accidents took place when an explosion at Gresford Colliery in Wales killed 266 men.
# 1979 – An American Vela satellite detected an unidentified flash of light near the Prince Edward Islands in the Indian Ocean, thought to be a nuclear weapons test.
# 1994 – The Nordhordland Bridge, crossing Salhusfjorden between Klauvaneset and Flatøy in Vestland, and Norway's second-longest bridge, officially opened.

# %% [markdown]
# ### Functionalize this process i.e. write a compact function to extract "On this day" text from Wikipedia Home Page

# %%
def wiki_on_this_day(url="https://en.wikipedia.org/wiki/Main_Page"):
    """
    Extracts the text corresponding to the "On this day" section on the Wikipedia Home Page.
    Accepts the Wikipedia Home Page URL as a string, a default URL is provided.
    """
    import requests
    from bs4 import BeautifulSoup
    
    wiki_home = str(url)
    response = requests.get(wiki_home)
    
    def status_check(r):
        if r.status_code==200:
            return 1
        else:
            return -1
    
    status = status_check(response)
    if status==1:
        contents = decode_content(response,encoding_check(response))
    else:
        print("Sorry could not reach the web page!")
        return -1
    
    soup = BeautifulSoup(contents, 'html.parser')
    text_list=[]
    
    for d in soup.find_all('div'):
            if (d.get('id')=='mp-otd'):
                for i in d.find_all('ul'):
                    text_list.append(i.text)
    
    return (text_list[0])

# %%
print(wiki_on_this_day())
# Out:
# 1586 – Eighty Years' War: Spanish forces defeated an Anglo-Dutch army at the Battle of Zutphen.
# 1869 – Das Rheingold, the first of four operas in Der Ring des Nibelungen by the German composer Richard Wagner (pictured), was first performed in Munich.
# 1934 – One of Britain's worst mining accidents took place when an explosion at Gresford Colliery in Wales killed 266 men.
# 1979 – An American Vela satellite detected an unidentified flash of light near the Prince Edward Islands in the Indian Ocean, thought to be a nuclear weapons test.
# 1994 – The Nordhordland Bridge, crossing Salhusfjorden between Klauvaneset and Flatøy in Vestland, and Norway's second-longest bridge, officially opened.

# %% [markdown]
# #### A wrong URL produces an error message as expected

# %%
print(wiki_on_this_day("https://en.wikipedia.org/wiki/Main_Page1"))
# Out:
# Sorry could not reach the web page!
# -1
