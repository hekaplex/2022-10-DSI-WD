# %% [markdown]
# # Pandas Basics

# %%
#row centric complex data type
# aka a list of lists
children = ["Andrew","Laura","Joe"]
lol_children = [[c, len(c)]  for c in children]
lol_children
# Out:
# [['Andrew', 6], ['Laura', 5], ['Joe', 3]]

# %%
# may need to run on download from python.org
# %pip install pandas

# %%
#DataFrame from LOL
#alias for package
import pandas as pd
df_lol_children = pd.DataFrame(lol_children,columns = ["child","charlen"])
df_lol_children
# Out:
#     child  charlen
# 0  Andrew        6
# 1   Laura        5
# 2     Joe        3

# %%
df = pd.read_csv(r"X:\SonyDump\PX\minkind\Documents\zilliantanalytics.tnb.com\build-final_20080815\datawarehousing\sampleData\orders.txt")
len(df)
# Out:
# 2771

# %%
#column centric complex data type
# aka dictionary where values are lists
len_char = [len(c) for c in children]
print(len_char)
d_children = {"child": children, "charlen": len_char}
print(d_children)

# %%
d_children["child"][2] + ","  +str( d_children["charlen"][2])

# %%
#DataFrame from dictionary of lists
df_d_children = pd.DataFrame(d_children)
df_d_children

# %%
type(df_lol_children)

# %%
df_lol_children.info()

# %%
list(df_d_children.columns)

# %%
# descriptive stats for numbers
df_d_children.describe()
# Out:
#         charlen
# count  3.000000
# mean   4.666667
# std    1.527525
# min    3.000000
# 25%    4.000000
# 50%    5.000000
# 75%    5.500000
# max    6.000000

# %%
# descriptive stats for string
df_d_children.describe(include="O")
# Out:
#         child
# count       3
# unique      3
# top     Laura
# freq        1

# %% [markdown]
# ## Get the data

# %%
poll_url = 'http://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv'
polls = pd.read_csv(poll_url)

# %%
len(list(polls.columns))
# Out:
# 27

# %%
list(polls.columns)
# Out:
# ['cycle',
#  'branch',
#  'type',
#  'matchup',
#  'forecastdate',
#  'state',
#  'startdate',
#  'enddate',
#  'pollster',
#  'grade',
#  'samplesize',
#  'population',
#  'poll_wt',
#  'rawpoll_clinton',
#  'rawpoll_trump',
#  'rawpoll_johnson',
#  'rawpoll_mcmullin',
#  'adjpoll_clinton',
#  'adjpoll_trump',
#  'adjpoll_johnson',
#  'adjpoll_mcmullin',
#  'multiversions',
#  'url',
#  'poll_id',
#  'question_id',
#  'createddate',
#  'timestamp']

# %%
list(polls.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12624 entries, 0 to 12623
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cycle             12624 non-null  int64
#  1   branch            12624 non-null  object
#  2   type              12624 non-null  object
#  3   matchup           12624 non-null  object
#  4   forecastdate      12624 non-null  object
#  5   state             12624 non-null  object
#  6   startdate         12624 non-null  object
#  7   enddate           12624 non-null  object
#  8   pollster          12624 non-null  object
#  9   grade             11337 non-null  object
#  10  samplesize        12621 non-null  float64
#  11  population        12624 non-null  object
#  12  poll_wt           12624 non-null  float64
#  13  rawpoll_clinton   12624 non-null  float64
#  14  rawpoll_trump     12624 non-null  float64
#  15  rawpoll_johnson   8397 non-null   float64
#  16  rawpoll_mcmullin  90 non-null     float64
#  17  adjpoll_clinton   12624 non-null  float64
#  18  adjpoll_trump     12624 non-null  float64
#  19  adjpoll_johnson   8397 non-null   float64
#  20  adjpoll_mcmullin  90 non-null     float64
#  21  multiversions     36 non-null     object
#  22  url               12621 non-null  object
#  23  poll_id           12624 non-null  int64
#  24  question_id       12624 non-null  int64
#  25  createddate       12624 non-null  object
#  26  timestamp         12624 non-null  object
# dtypes: float64(10), int64(3), object(14)
# memory usage: 2.6+ MB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-187a429bbf7f> in <module>
# ----> 1 list(polls.info())
#
# TypeError: 'NoneType' object is not iterable

# %%
#SELECT startdate, count(*) from polls group by startdate
df_poll_value_counts = pd.DataFrame(data=polls.startdate.value_counts(), columns = ["date","rowcount"])

# %%
polls.startdate.value_counts()
# Out:
# 2016-10-20    480
# 2016-11-01    465
# 2016-10-25    408
# 2016-10-04    351
# 2016-10-27    300
#              ...
# 2016-01-27      3
# 2016-05-07      3
# 2015-11-30      3
# 2016-01-26      3
# 2016-02-07      3
# Name: startdate, Length: 352, dtype: int64

# %%
df_poll_value_counts
# Out:
# Empty DataFrame
# Columns: [date, rowcount]
# Index: []

# %%
polls["startdate"].dtype
# Out:
# dtype('<M8[ns]')

# %%
polls["startdate"] = pd.to_datetime(polls["startdate"])

# %%
polls["enddate"] = pd.to_datetime(polls["enddate"])

# %%
polls.head(5).T
# Out:
#                                                                   0  \
# cycle                                                          2016
# branch                                                    President
# type                                                     polls-plus
# matchup                               Clinton vs. Trump vs. Johnson
# forecastdate                                                11/8/16
# state                                                          U.S.
# startdate                                       2016-11-03 00:00:00
# enddate                                         2016-11-06 00:00:00
# pollster                                   ABC News/Washington Post
# grade                                                            A+
# samplesize                                                   2220.0
# population                                                       lv
# poll_wt                                                    8.720654
# rawpoll_clinton                                                47.0
# rawpoll_trump                                                  43.0
# rawpoll_johnson                                                 4.0
# rawpoll_mcmullin                                                NaN
# adjpoll_clinton                                            45.20163
# adjpoll_trump                                               41.7243
# adjpoll_johnson                                            4.626221
# adjpoll_mcmullin                                                NaN
# multiversions                                                   NaN
# url               https://www.washingtonpost.com/news/the-fix/wp...
# poll_id                                                       48630
# question_id                                                   76192
# createddate                                                 11/7/16
# timestamp                                      09:35:33  8 Nov 2016
#
#                                                                   1  \
# cycle                                                          2016
# branch                                                    President
# type                                                     polls-plus
# matchup                               Clinton vs. Trump vs. Johnson
# forecastdate                                                11/8/16
# state                                                          U.S.
# startdate                                       2016-11-01 00:00:00
# enddate                                         2016-11-07 00:00:00
# pollster                                    Google Consumer Surveys
# grade                                                             B
# samplesize                                                  26574.0
# population                                                       lv
# poll_wt                                                    7.628472
# rawpoll_clinton                                               38.03
# rawpoll_trump                                                 35.69
# rawpoll_johnson                                                5.46
# rawpoll_mcmullin                                                NaN
# adjpoll_clinton                                            43.34557
# adjpoll_trump                                              41.21439
# adjpoll_johnson                                            5.175792
# adjpoll_mcmullin                                                NaN
# multiversions                                                   NaN
# url               https://datastudio.google.com/u/0/#/org//repor...
# poll_id                                                       48847
# question_id                                                   76443
# createddate                                                 11/7/16
# timestamp                                      09:35:33  8 Nov 2016
#
#                                                                   2  \
# cycle                                                          2016
# branch                                                    President
# type                                                     polls-plus
# matchup                               Clinton vs. Trump vs. Johnson
# forecastdate                                                11/8/16
# state                                                          U.S.
# startdate                                       2016-11-02 00:00:00
# enddate                                         2016-11-06 00:00:00
# pollster                                                      Ipsos
# grade                                                            A-
# samplesize                                                   2195.0
# population                                                       lv
# poll_wt                                                    6.424334
# rawpoll_clinton                                                42.0
# rawpoll_trump                                                  39.0
# rawpoll_johnson                                                 6.0
# rawpoll_mcmullin                                                NaN
# adjpoll_clinton                                            42.02638
# adjpoll_trump                                               38.8162
# adjpoll_johnson                                            6.844734
# adjpoll_mcmullin                                                NaN
# multiversions                                                   NaN
# url               http://projects.fivethirtyeight.com/polls/2016...
# poll_id                                                       48922
# question_id                                                   76636
# createddate                                                 11/8/16
# timestamp                                      09:35:33  8 Nov 2016
#
#                                                                   3  \
# cycle                                                          2016
# branch                                                    President
# type                                                     polls-plus
# matchup                               Clinton vs. Trump vs. Johnson
# forecastdate                                                11/8/16
# state                                                          U.S.
# startdate                                       2016-11-04 00:00:00
# enddate                                         2016-11-07 00:00:00
# pollster                                                     YouGov
# grade                                                             B
# samplesize                                                   3677.0
# population                                                       lv
# poll_wt                                                    6.087135
# rawpoll_clinton                                                45.0
# rawpoll_trump                                                  41.0
# rawpoll_johnson                                                 5.0
# rawpoll_mcmullin                                                NaN
# adjpoll_clinton                                            45.65676
# adjpoll_trump                                              40.92004
# adjpoll_johnson                                            6.069454
# adjpoll_mcmullin                                                NaN
# multiversions                                                   NaN
# url               https://d25d2506sfb94s.cloudfront.net/cumulus_...
# poll_id                                                       48687
# question_id                                                   76262
# createddate                                                 11/7/16
# timestamp                                      09:35:33  8 Nov 2016
#
#                                                                   4
# cycle                                                          2016
# branch                                                    President
# type                                                     polls-plus
# matchup                               Clinton vs. Trump vs. Johnson
# forecastdate                                                11/8/16
# state                                                          U.S.
# startdate                                       2016-11-03 00:00:00
# enddate                                         2016-11-06 00:00:00
# pollster                                           Gravis Marketing
# grade                                                            B-
# samplesize                                                  16639.0
# population                                                       rv
# poll_wt                                                    5.316449
# rawpoll_clinton                                                47.0
# rawpoll_trump                                                  43.0
# rawpoll_johnson                                                 3.0
# rawpoll_mcmullin                                                NaN
# adjpoll_clinton                                            46.84089
# adjpoll_trump                                              42.33184
# adjpoll_johnson                                            3.726098
# adjpoll_mcmullin                                                NaN
# multiversions                                                   NaN
# url               http://www.gravispolls.com/2016/11/final-natio...
# poll_id                                                       48848
# question_id                                                   76444
# createddate                                                 11/7/16
# timestamp                                      09:35:33  8 Nov 2016

# %%
polls["forecastdate"] = pd.to_datetime(polls["forecastdate"])

# %%
polls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12624 entries, 0 to 12623
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cycle             12624 non-null  int64
#  1   branch            12624 non-null  object
#  2   type              12624 non-null  object
#  3   matchup           12624 non-null  object
#  4   forecastdate      12624 non-null  datetime64[ns]
#  5   state             12624 non-null  object
#  6   startdate         12624 non-null  datetime64[ns]
#  7   enddate           12624 non-null  datetime64[ns]
#  8   pollster          12624 non-null  object
#  9   grade             11337 non-null  object
#  10  samplesize        12621 non-null  float64
#  11  population        12624 non-null  object
#  12  poll_wt           12624 non-null  float64
#  13  rawpoll_clinton   12624 non-null  float64
#  14  rawpoll_trump     12624 non-null  float64
#  15  rawpoll_johnson   8397 non-null   float64
#  16  rawpoll_mcmullin  90 non-null     float64
#  17  adjpoll_clinton   12624 non-null  float64
#  18  adjpoll_trump     12624 non-null  float64
#  19  adjpoll_johnson   8397 non-null   float64
#  20  adjpoll_mcmullin  90 non-null     float64
#  21  multiversions     36 non-null     object
#  22  url               12621 non-null  object
#  23  poll_id           12624 non-null  int64
#  24  question_id       12624 non-null  int64
#  25  createddate       12624 non-null  object
#  26  timestamp         12624 non-null  object
# dtypes: datetime64[ns](3), float64(10), int64(3), object(11)
# memory usage: 2.6+ MB

# %%
polls.columns

# %%
polls.tail()
# Out:
#        cycle     branch        type                        matchup  \
# 12619   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12621   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12622   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12623   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate          state  startdate    enddate  \
# 12619   2016-11-08  New Hampshire 2016-07-09 2016-07-18
# 12620   2016-11-08      Wisconsin 2016-10-21 2016-11-02
# 12621   2016-11-08       New York 2016-08-07 2016-08-10
# 12622   2016-11-08       Virginia 2016-09-30 2016-10-06
# 12623   2016-11-08      Wisconsin 2016-06-09 2016-06-12
#
#                           pollster grade  ...  adjpoll_clinton adjpoll_trump  \
# 12619  University of New Hampshire    B+  ...         40.24983      43.04717
# 12620                        Ipsos    A-  ...         46.54218      38.96884
# 12621                Siena College     A  ...         53.83622      32.47939
# 12622                        Ipsos    A-  ...         49.57558      39.96954
# 12623         Marquette University     A  ...         46.40999      39.19839
#
#        adjpoll_johnson  adjpoll_mcmullin  multiversions  \
# 12619         6.924110               NaN            NaN
# 12620              NaN               NaN            NaN
# 12621         3.881193               NaN            NaN
# 12622              NaN               NaN            NaN
# 12623              NaN               NaN            NaN
#
#                                                      url  poll_id  \
# 12619  https://cola.unh.edu/sites/cola.unh.edu/files/...    44650
# 12620          http://www.reuters.com/statesofthenation/    48259
# 12621  https://www.siena.edu/assets/files/news/SNY081...    44852
# 12622          http://www.reuters.com/statesofthenation/    46675
# 12623  https://law.marquette.edu/poll/2016/06/15/new-...    44341
#
#        question_id  createddate             timestamp
# 12619        68189      7/21/16  09:14:14  8 Nov 2016
# 12620        75560      11/3/16  09:14:14  8 Nov 2016
# 12621        68743      8/15/16  09:14:14  8 Nov 2016
# 12622        72969     10/10/16  09:14:14  8 Nov 2016
# 12623        66966      6/15/16  09:14:14  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Sort the data

# %%
polls.enddate.min()
# Out:
# Timestamp('2015-11-08 00:00:00')

# %%
polls.sort_values('enddate', ascending=False, inplace=True)
polls.head()
# Out:
#       cycle     branch        type                        matchup  \
# 299    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 412    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 8499   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 345    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4779   2016  President    now-cast  Clinton vs. Trump vs. Johnson
#
#      forecastdate      state  startdate    enddate                 pollster  \
# 299    2016-11-08   Delaware 2016-11-01 2016-11-07             SurveyMonkey
# 412    2016-11-08       Iowa 2016-11-01 2016-11-07  Google Consumer Surveys
# 8499   2016-11-08   Michigan 2016-11-01 2016-11-07             SurveyMonkey
# 345    2016-11-08  Wisconsin 2016-11-01 2016-11-07  Google Consumer Surveys
# 4779   2016-11-08   Delaware 2016-11-01 2016-11-07  Google Consumer Surveys
#
#      grade  ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  \
# 299     C-  ...         48.59150      38.32726         3.692430
# 412      B  ...         40.89573      39.24911         3.855792
# 8499    C-  ...         42.54280      41.43171         5.676823
# 345      B  ...         48.49226      36.57750         3.745792
# 4779     B  ...         47.24413      35.89639         6.505080
#
#       adjpoll_mcmullin  multiversions  \
# 299                NaN            NaN
# 412                NaN            NaN
# 8499               NaN            NaN
# 345                NaN            NaN
# 4779               NaN            NaN
#
#                                                     url  poll_id  question_id  \
# 299   https://www.surveymonkey.com/elections/map?pol...    48868        76558
# 412   https://datastudio.google.com/u/0/#/org//repor...    48805        76394
# 8499  https://www.surveymonkey.com/elections/map?pol...    48882        76572
# 345   https://datastudio.google.com/u/0/#/org//repor...    48842        76431
# 4779  https://datastudio.google.com/u/0/#/org//repor...    48801        76390
#
#       createddate             timestamp
# 299       11/8/16  09:35:33  8 Nov 2016
# 412       11/7/16  09:35:33  8 Nov 2016
# 8499      11/8/16  09:14:14  8 Nov 2016
# 345       11/7/16  09:35:33  8 Nov 2016
# 4779      11/7/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Use lists, slices, tuples, and dictionary objects

# %% [markdown]
# ### A list

# %%
# columns=['cycle','branch','matchup','forecastdate'], inplace=True
dict_input = {"columns":['cycle','branch','matchup','forecastdate'], "inplace":True}
polls.drop(**dict_input)
polls.head(2)
# Out:
#            type     state  startdate    enddate                 pollster  \
# 299  polls-plus  Delaware 2016-11-01 2016-11-07             SurveyMonkey
# 412  polls-plus      Iowa 2016-11-01 2016-11-07  Google Consumer Surveys
#
#     grade  samplesize population   poll_wt  rawpoll_clinton  ...  \
# 299    C-       367.0         lv  1.237250            50.00  ...
# 412     B       442.0         lv  0.850219            35.57  ...
#
#      adjpoll_clinton  adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 299         48.59150       38.32726         3.692430               NaN
# 412         40.89573       39.24911         3.855792               NaN
#
#      multiversions                                                url  \
# 299            NaN  https://www.surveymonkey.com/elections/map?pol...
# 412            NaN  https://datastudio.google.com/u/0/#/org//repor...
#
#      poll_id question_id createddate             timestamp
# 299    48868       76558     11/8/16  09:35:33  8 Nov 2016
# 412    48805       76394     11/7/16  09:35:33  8 Nov 2016
#
# [2 rows x 23 columns]

# %% [markdown]
# ### A dictionary, ranges and comprehension

# %%
polls = polls.rename(columns={'adjpoll_clinton':'Clinton',
                      'adjpoll_trump':'Trump'})
polls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12624 entries, 299 to 12287
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type              12624 non-null  object
#  1   state             12624 non-null  object
#  2   startdate         12624 non-null  datetime64[ns]
#  3   enddate           12624 non-null  datetime64[ns]
#  4   pollster          12624 non-null  object
#  5   grade             11337 non-null  object
#  6   samplesize        12621 non-null  float64
#  7   population        12624 non-null  object
#  8   poll_wt           12624 non-null  float64
#  9   rawpoll_clinton   12624 non-null  float64
#  10  rawpoll_trump     12624 non-null  float64
#  11  rawpoll_johnson   8397 non-null   float64
#  12  rawpoll_mcmullin  90 non-null     float64
#  13  Clinton           12624 non-null  float64
#  14  Trump             12624 non-null  float64
#  15  adjpoll_johnson   8397 non-null   float64
#  16  adjpoll_mcmullin  90 non-null     float64
#  17  multiversions     36 non-null     object
#  18  url               12621 non-null  object
#  19  poll_id           12624 non-null  int64
#  20  question_id       12624 non-null  int64
#  21  createddate       12624 non-null  object
#  22  timestamp         12624 non-null  object
# dtypes: datetime64[ns](2), float64(10), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
len(polls)
# Out:
# 12624

# %%
num = [f for f in range(0,12624,24)]
num
# Out:
# [0,
#  24,
#  48,
#  72,
#  96,
#  120,
#  144,
#  168,
#  192,
#  216,
#  240,
#  264,
#  288,
#  312,
#  336,
#  360,
#  384,
#  408,
#  432,
#  456,
#  480,
#  504,
#  528,
#  552,
#  576,
#  600,
#  624,
#  648,
#  672,
#  696,
#  720,
#  744,
#  768,
#  792,
#  816,
#  840,
#  864,
#  888,
#  912,
#  936,
#  960,
#  984,
#  1008,
#  1032,
#  1056,
#  1080,
#  1104,
#  1128,
#  1152,
#  1176,
#  1200,
#  1224,
#  1248,
#  1272,
#  1296,
#  1320,
#  1344,
#  1368,
#  1392,
#  1416,
#  1440,
#  1464,
#  1488,
#  1512,
#  1536,
#  1560,
#  1584,
#  1608,
#  1632,
#  1656,
#  1680,
#  1704,
#  1728,
#  1752,
#  1776,
#  1800,
#  1824,
#  1848,
#  1872,
#  1896,
#  1920,
#  1944,
#  1968,
#  1992,
#  2016,
#  2040,
#  2064,
#  2088,
#  2112,
#  2136,
#  2160,
#  2184,
#  2208,
#  2232,
#  2256,
#  2280,
#  2304,
#  2328,
#  2352,
#  2376,
#  2400,
#  2424,
#  2448,
#  2472,
#  2496,
#  2520,
#  2544,
#  2568,
#  2592,
#  2616,
#  2640,
#  2664,
#  2688,
#  2712,
#  2736,
#  2760,
#  2784,
#  2808,
#  2832,
#  2856,
#  2880,
#  2904,
#  2928,
#  2952,
#  2976,
#  3000,
#  3024,
#  3048,
#  3072,
#  3096,
#  3120,
#  3144,
#  3168,
#  3192,
#  3216,
#  3240,
#  3264,
#  3288,
#  3312,
#  3336,
#  3360,
#  3384,
#  3408,
#  3432,
#  3456,
#  3480,
#  3504,
#  3528,
#  3552,
#  3576,
#  3600,
#  3624,
#  3648,
#  3672,
#  3696,
#  3720,
#  3744,
#  3768,
#  3792,
#  3816,
#  3840,
#  3864,
#  3888,
#  3912,
#  3936,
#  3960,
#  3984,
#  4008,
#  4032,
#  4056,
#  4080,
#  4104,
#  4128,
#  4152,
#  4176,
#  4200,
#  4224,
#  4248,
#  4272,
#  4296,
#  4320,
#  4344,
#  4368,
#  4392,
#  4416,
#  4440,
#  4464,
#  4488,
#  4512,
#  4536,
#  4560,
#  4584,
#  4608,
#  4632,
#  4656,
#  4680,
#  4704,
#  4728,
#  4752,
#  4776,
#  4800,
#  4824,
#  4848,
#  4872,
#  4896,
#  4920,
#  4944,
#  4968,
#  4992,
#  5016,
#  5040,
#  5064,
#  5088,
#  5112,
#  5136,
#  5160,
#  5184,
#  5208,
#  5232,
#  5256,
#  5280,
#  5304,
#  5328,
#  5352,
#  5376,
#  5400,
#  5424,
#  5448,
#  5472,
#  5496,
#  5520,
#  5544,
#  5568,
#  5592,
#  5616,
#  5640,
#  5664,
#  5688,
#  5712,
#  5736,
#  5760,
#  5784,
#  5808,
#  5832,
#  5856,
#  5880,
#  5904,
#  5928,
#  5952,
#  5976,
#  6000,
#  6024,
#  6048,
#  6072,
#  6096,
#  6120,
#  6144,
#  6168,
#  6192,
#  6216,
#  6240,
#  6264,
#  6288,
#  6312,
#  6336,
#  6360,
#  6384,
#  6408,
#  6432,
#  6456,
#  6480,
#  6504,
#  6528,
#  6552,
#  6576,
#  6600,
#  6624,
#  6648,
#  6672,
#  6696,
#  6720,
#  6744,
#  6768,
#  6792,
#  6816,
#  6840,
#  6864,
#  6888,
#  6912,
#  6936,
#  6960,
#  6984,
#  7008,
#  7032,
#  7056,
#  7080,
#  7104,
#  7128,
#  7152,
#  7176,
#  7200,
#  7224,
#  7248,
#  7272,
#  7296,
#  7320,
#  7344,
#  7368,
#  7392,
#  7416,
#  7440,
#  7464,
#  7488,
#  7512,
#  7536,
#  7560,
#  7584,
#  7608,
#  7632,
#  7656,
#  7680,
#  7704,
#  7728,
#  7752,
#  7776,
#  7800,
#  7824,
#  7848,
#  7872,
#  7896,
#  7920,
#  7944,
#  7968,
#  7992,
#  8016,
#  8040,
#  8064,
#  8088,
#  8112,
#  8136,
#  8160,
#  8184,
#  8208,
#  8232,
#  8256,
#  8280,
#  8304,
#  8328,
#  8352,
#  8376,
#  8400,
#  8424,
#  8448,
#  8472,
#  8496,
#  8520,
#  8544,
#  8568,
#  8592,
#  8616,
#  8640,
#  8664,
#  8688,
#  8712,
#  8736,
#  8760,
#  8784,
#  8808,
#  8832,
#  8856,
#  8880,
#  8904,
#  8928,
#  8952,
#  8976,
#  9000,
#  9024,
#  9048,
#  9072,
#  9096,
#  9120,
#  9144,
#  9168,
#  9192,
#  9216,
#  9240,
#  9264,
#  9288,
#  9312,
#  9336,
#  9360,
#  9384,
#  9408,
#  9432,
#  9456,
#  9480,
#  9504,
#  9528,
#  9552,
#  9576,
#  9600,
#  9624,
#  9648,
#  9672,
#  9696,
#  9720,
#  9744,
#  9768,
#  9792,
#  9816,
#  9840,
#  9864,
#  9888,
#  9912,
#  9936,
#  9960,
#  9984,
#  10008,
#  10032,
#  10056,
#  10080,
#  10104,
#  10128,
#  10152,
#  10176,
#  10200,
#  10224,
#  10248,
#  10272,
#  10296,
#  10320,
#  10344,
#  10368,
#  10392,
#  10416,
#  10440,
#  10464,
#  10488,
#  10512,
#  10536,
#  10560,
#  10584,
#  10608,
#  10632,
#  10656,
#  10680,
#  10704,
#  10728,
#  10752,
#  10776,
#  10800,
#  10824,
#  10848,
#  10872,
#  10896,
#  10920,
#  10944,
#  10968,
#  10992,
#  11016,
#  11040,
#  11064,
#  11088,
#  11112,
#  11136,
#  11160,
#  11184,
#  11208,
#  11232,
#  11256,
#  11280,
#  11304,
#  11328,
#  11352,
#  11376,
#  11400,
#  11424,
#  11448,
#  11472,
#  11496,
#  11520,
#  11544,
#  11568,
#  11592,
#  11616,
#  11640,
#  11664,
#  11688,
#  11712,
#  11736,
#  11760,
#  11784,
#  11808,
#  11832,
#  11856,
#  11880,
#  11904,
#  11928,
#  11952,
#  11976,
#  12000,
#  12024,
#  12048,
#  12072,
#  12096,
#  12120,
#  12144,
#  12168,
#  12192,
#  12216,
#  12240,
#  12264,
#  12288,
#  12312,
#  12336,
#  12360,
#  12384,
#  12408,
#  12432,
#  12456,
#  12480,
#  12504,
#  12528,
#  12552,
#  12576,
#  12600]

# %%
num[0:100]
# Out:
# [0,
#  24,
#  48,
#  72,
#  96,
#  120,
#  144,
#  168,
#  192,
#  216,
#  240,
#  264,
#  288,
#  312,
#  336,
#  360,
#  384,
#  408,
#  432,
#  456,
#  480,
#  504,
#  528,
#  552,
#  576,
#  600,
#  624,
#  648,
#  672,
#  696,
#  720,
#  744,
#  768,
#  792,
#  816,
#  840,
#  864,
#  888,
#  912,
#  936,
#  960,
#  984,
#  1008,
#  1032,
#  1056,
#  1080,
#  1104,
#  1128,
#  1152,
#  1176,
#  1200,
#  1224,
#  1248,
#  1272,
#  1296,
#  1320,
#  1344,
#  1368,
#  1392,
#  1416,
#  1440,
#  1464,
#  1488,
#  1512,
#  1536,
#  1560,
#  1584,
#  1608,
#  1632,
#  1656,
#  1680,
#  1704,
#  1728,
#  1752,
#  1776,
#  1800,
#  1824,
#  1848,
#  1872,
#  1896,
#  1920,
#  1944,
#  1968,
#  1992,
#  2016,
#  2040,
#  2064,
#  2088,
#  2112,
#  2136,
#  2160,
#  2184,
#  2208,
#  2232,
#  2256,
#  2280,
#  2304,
#  2328,
#  2352,
#  2376]

# %% [markdown]
# ### Two slices

# %%
type(polls.loc[0:100:10,'state':'grade'])
# Out:
# pandas.core.frame.DataFrame

# %%
rng = range(0,12624)
lrng = [l for l in rng]
len(lrng[0:100:10])
# Out:
# 10

# %%
len(polls)
# Out:
# 12624

# %%
polls.loc()

# %%
polls.loc()
# Out:
#             type       state  startdate    enddate                 pollster  \
# 299   polls-plus    Delaware 2016-11-01 2016-11-07             SurveyMonkey
# 412   polls-plus        Iowa 2016-11-01 2016-11-07  Google Consumer Surveys
# 8499  polls-only    Michigan 2016-11-01 2016-11-07             SurveyMonkey
# 345   polls-plus   Wisconsin 2016-11-01 2016-11-07  Google Consumer Surveys
# 4779    now-cast    Delaware 2016-11-01 2016-11-07  Google Consumer Surveys
# ...          ...         ...        ...        ...                      ...
# 8556  polls-only  New Jersey 2016-11-01 2016-11-07             SurveyMonkey
# 8558  polls-only    Missouri 2016-11-01 2016-11-07             SurveyMonkey
# 4832    now-cast     Wyoming 2016-11-01 2016-11-07  Google Consumer Surveys
# 8561  polls-only      Kansas 2016-11-01 2016-11-07             SurveyMonkey
# 4856    now-cast      Alaska 2016-11-01 2016-11-07  Google Consumer Surveys
#
#      grade  samplesize population   poll_wt  rawpoll_clinton  ...   Clinton  \
# 299     C-       367.0         lv  1.237250            50.00  ...  48.59150
# 412      B       442.0         lv  0.850219            35.57  ...  40.89573
# 8499    C-      3145.0         lv  2.684582            44.00  ...  42.54280
# 345      B       914.0         lv  1.032963            43.17  ...  48.49226
# 4779     B       149.0         lv  0.503396            41.91  ...  47.24413
# ...    ...         ...        ...       ...              ...  ...       ...
# 8556    C-      1377.0         lv  2.251136            52.00  ...  50.54602
# 8558    C-      1368.0         lv  2.235764            40.00  ...  38.53631
# 4832     B       113.0         lv  0.420884            25.04  ...  30.38390
# 8561    C-      1311.0         lv  2.217888            36.00  ...  34.54708
# 4856     B        97.0         lv  0.376677            23.23  ...  28.57927
#
#          Trump  adjpoll_johnson  adjpoll_mcmullin  multiversions  \
# 299   38.32726         3.692430               NaN            NaN
# 412   39.24911         3.855792               NaN            NaN
# 8499  41.43171         5.676823               NaN            NaN
# 345   36.57750         3.745792               NaN            NaN
# 4779  35.89639         6.505080               NaN            NaN
# ...        ...              ...               ...            ...
# 8556  36.43336         1.676822               NaN            NaN
# 8558  47.42836         5.676823               NaN            NaN
# 4832  52.61143         8.515079               NaN            NaN
# 8561  48.43392         6.676823               NaN            NaN
# 4856  52.93420         9.145081               NaN            NaN
#
#                                                     url  poll_id question_id  \
# 299   https://www.surveymonkey.com/elections/map?pol...    48868       76558
# 412   https://datastudio.google.com/u/0/#/org//repor...    48805       76394
# 8499  https://www.surveymonkey.com/elections/map?pol...    48882       76572
# 345   https://datastudio.google.com/u/0/#/org//repor...    48842       76431
# 4779  https://datastudio.google.com/u/0/#/org//repor...    48801       76390
# ...                                                 ...      ...         ...
# 8556  https://www.surveymonkey.com/elections/map?pol...    48890       76580
# 8558  https://www.surveymonkey.com/elections/map?pol...    48885       76575
# 4832  https://datastudio.google.com/u/0/#/org//repor...    48845       76434
# 8561  https://www.surveymonkey.com/elections/map?pol...    48876       76566
# 4856  https://datastudio.google.com/u/0/#/org//repor...    48793       76382
#
#      createddate             timestamp
# 299      11/8/16  09:35:33  8 Nov 2016
# 412      11/7/16  09:35:33  8 Nov 2016
# 8499     11/8/16  09:14:14  8 Nov 2016
# 345      11/7/16  09:35:33  8 Nov 2016
# 4779     11/7/16  09:24:53  8 Nov 2016
# ...          ...                   ...
# 8556     11/8/16  09:14:14  8 Nov 2016
# 8558     11/8/16  09:14:14  8 Nov 2016
# 4832     11/7/16  09:24:53  8 Nov 2016
# 8561     11/8/16  09:14:14  8 Nov 2016
# 4856     11/7/16  09:24:53  8 Nov 2016
#
# [100 rows x 23 columns]

# %%
foo = polls.loc[0:100:10,'state':'grade'].index
foo
# Out:
# Int64Index([    0,  4825,  4805,  4888,  4863,   374,  4735,  4767,  4776,
#              4897,
#             ...
#              8531,  1672,  4050, 10070,   190,  8275,  8483,  5077, 10221,
#                93],
#            dtype='int64', length=138)

# %%
polls.loc[0:20:10,['state','grade']]
# Out:
#              state grade
# 0             U.S.    A+
# 4825         Maine    C-
# 4805   Mississippi    C-
# 4888    Washington    C-
# 4863      Maryland    C-
# 374   Pennsylvania    A-
# 4735         Maine    A-
# 4767        Hawaii    C-
# 4776  Rhode Island    C-
# 4897  North Dakota     B
# 95         Georgia     C
# 5025         Texas    C-
# 6             U.S.    A-

# %%
",".join([str(f) for f in foo])
# Out:
# '0,4825,4805,4888,4863,374,4735,4767,4776,4897,95,5025,6,27,210,4918,185,202,9070,464,527,587,495,503,514,489,555,4718,597,542,536,547,935,4334,8462,4255,912,8457,1842,1492,1519,1687,5915,1272,9939,5715,5694,10178,1338,9974,1223,9068,5540,660,151,55,108,998,4223,5912,1969,5961,8649,9135,10400,5186,1618,1656,5650,5219,5226,1693,10109,9646,9721,9793,9460,9406,9620,4557,5691,8617,9401,9821,4771,9923,6150,14,1434,1207,1237,6208,1315,1392,1013,1184,1812,10512,44,4837,8660,1759,5897,453,4670,1853,9705,5630,5944,5721,6185,2009,6037,8460,6095,4273,6316,10266,802,5012,4243,1496,629,6353,156,4364,1511,10120,8531,1672,4050,10070,190,8275,8483,5077,10221,93'
